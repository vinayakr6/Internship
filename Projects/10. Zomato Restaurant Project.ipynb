# %% [markdown]
# ##### Zomato Restaurant Project - Vinayak Ratan

# %% [markdown]
# ##### Problem Statement:
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# ##### Data Storage:
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
#  Country code
#  Country name
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the
# following variables:
# • Restaurant Id: Unique id of every restaurant across various cities of the world
# • Restaurant Name: Name of the restaurant
# • Country Code: Country in which restaurant is located
# • City: City in which restaurant is located
# • Address: Address of the restaurant
# • Locality: Location in the city
# • Locality Verbose: Detailed description of the locality
# • Longitude: Longitude coordinate of the restaurant&#39;s location
# • Latitude: Latitude coordinate of the restaurant&#39;s location
# • Cuisines: Cuisines offered by the restaurant
# • Average Cost for two: Cost for two people in different currencies ��
# • Currency: Currency of the country
# • Has Table booking: yes/no
# • Has Online delivery: yes/ no
# • Is delivering: yes/ no
# • Switch to order menu: yes/no
# • Price range: range of price of food
# • Aggregate Rating: Average rating out of 5
# • Rating color: depending upon the average rating color
# • Rating text: text on the basis of rating of rating
# • Votes: Number of ratings casted by people
#
# ##### Problem statement : In this dataset predict 2 things –
# ##### 1) Average Cost for two
# ##### 2) Price range
#
# Hint : Use pandas merge operation -- pd.merge (df1,df2) to combine two datasets
# Downlaod Files:
# https://github.com/dsrscientist/dataset4/blob/main/Country-Code.xlsx
# https://github.com/dsrscientist/dataset4/blob/main/zomato.csv

# %%
# Importing # Importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Country code dataframe
df1 = pd.read_excel(r"E:\Data Trained\Notes & Repository\Github docs\Datasets\dataset4-main\Country-Code.xlsx")
df1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
# DataFrame Zomato.csv
df2 = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv", encoding="ISO-8859-1")
df2
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# Merging the above dataframes
zomato_df = pd.merge(df1,df2)
zomato_df.head()
# Out:
#    Country Code Country  Restaurant ID                        Restaurant Name  \
# 0             1   India        3400025                             Jahanpanah
# 1             1   India        3400341                    Rangrezz Restaurant
# 2             1   India        3400005                Time2Eat - Mama Chicken
# 3             1   India        3400021  Chokho Jeeman Marwari Jain Bhojanalya
# 4             1   India        3400017                         Pinch Of Spice
#
#    City                                            Address     Locality  \
# 0  Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 1  Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 2  Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 3  Agra  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 4  Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
# ...

# %%
zomato_df.tail()
# Out:
#       Country Code        Country  Restaurant ID  \
# 9546           216  United States       17697389
# 9547           216  United States       17697424
# 9548           216  United States       17697332
# 9549           216  United States       17694056
# 9550           216  United States       17559793
#
#                                Restaurant Name            City  \
# 9546                       The Screaming Eagle        Waterloo
# 9547                             The Thai Bowl        Waterloo
# 9548                Tokyo Japanese Steak House        Waterloo
# 9549  Theo Yianni's Authentic Greek Restaurant         Weirton
# 9550                 Fishpatrick's Crabby Cafe  Winchester Bay
#
#                                           Address        Locality  \
# 9546            228 E 4th St., Waterloo, IA 50703        Waterloo
# 9547      624 Sycamore Street, Waterloo, IA 50703        Waterloo
# 9548        1931 Sears Street, Waterloo, IA 50702        Waterloo
# ...

# %%
zomato_df.shape
# Out:
# (9551, 22)

# %%
# To display all the columns
pd.set_option('display.max_columns', None)
zomato_df.head()
# Out:
#    Country Code Country  Restaurant ID                        Restaurant Name  \
# 0             1   India        3400025                             Jahanpanah
# 1             1   India        3400341                    Rangrezz Restaurant
# 2             1   India        3400005                Time2Eat - Mama Chicken
# 3             1   India        3400021  Chokho Jeeman Marwari Jain Bhojanalya
# 4             1   India        3400017                         Pinch Of Spice
#
#    City                                            Address     Locality  \
# 0  Agra  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 1  Agra  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 2  Agra        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 3  Agra  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 4  Agra  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# ##### Basic Information

# %%
zomato_df.dtypes
# Out:
# Country Code              int64
# Country                  object
# Restaurant ID             int64
# Restaurant Name          object
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
# Separating the categorical and numerical datatypes for plotting purpose
cat = zomato_df.select_dtypes(include=['object']).columns
num = zomato_df.select_dtypes(include = ['int32','int64','float32','float64']).columns

# %%
cat
# Out:
# Index(['Country', 'Restaurant Name', 'City', 'Address', 'Locality',
#        'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Rating color', 'Rating text'],
#       dtype='object')

# %%
num
# Out:
# Index(['Country Code', 'Restaurant ID', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes'],
#       dtype='object')

# %%
# count plot for categorical variables 
for i in cat:
    print(zomato_df[i].value_counts())
    sns.countplot(x = i, data = zomato_df)
    plt.xticks(rotation = 'vertical')
    plt.show()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# UAE                 60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Qatar               20
# Singapore           20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64
# Cafe Coffee Day                       83
# Domino's Pizza                        79
# Subway                                63
# Green Chick Chop                      51
# McDonald's                            48
#                                       ..
# Chor Bizarre - Hotel Broadway          1
# Thugs - Hotel Broadway                 1
# The Kylin Experience - Holiday Inn     1
# Cafe on 3 - Holiday Inn                1
# Fishpatrick's Crabby Cafe              1
# Name: Restaurant Name, Length: 7446, dtype: int64
# New Delhi           5473
# Gurgaon             1118
# ...

# %% [markdown]
# - Maximum orders from country India
# - Most of the orders got average rating
# - Rating color and rating text both look same we can drop rating color

# %%
# When we look at the value counts, many features are there with column value count 1 or less compared to others 
# Hence replacing them with 'Others'
# Restaurant Name
need = zomato_df['Restaurant Name'].value_counts().index[:10]
zomato_df['Restaurant Name'] = np.where(zomato_df['Restaurant Name'].isin(need), zomato_df['Restaurant Name'], 'OTHER')
valCount = zomato_df['Restaurant Name'].value_counts()
print (valCount)
# Out:
# OTHER               9080
# Cafe Coffee Day       83
# Domino's Pizza        79
# Subway                63
# Green Chick Chop      51
# McDonald's            48
# Keventers             34
# Pizza Hut             30
# Giani                 29
# Baskin Robbins        28
# Barbeque Nation       26
# Name: Restaurant Name, dtype: int64

# %%
# City
need = zomato_df['City'].value_counts().index[:5]
zomato_df['City'] = np.where(zomato_df['City'].isin(need), zomato_df['City'], 'OTHER')
valCount = zomato_df['City'].value_counts()
print (valCount)
# Out:
# New Delhi    5473
# OTHER        1604
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
# Name: City, dtype: int64

# %% [markdown]
# - Address can be drop, instead we can use latitude and longitude to find the location

# %%
# Locality
need = zomato_df['Locality'].value_counts().index[:10]
zomato_df['Locality'] = np.where(zomato_df['Locality'].isin(need), zomato_df['Locality'], 'OTHER')
valCount = zomato_df['Locality'].value_counts()
print (valCount)
# Out:
# OTHER                  8663
# Connaught Place         122
# Rajouri Garden           99
# Shahdara                 87
# Defence Colony           86
# Malviya Nagar            85
# Pitampura                85
# Mayur Vihar Phase 1      84
# Rajinder Nagar           81
# Safdarjung               80
# Satyaniketan             79
# Name: Locality, dtype: int64

# %%
# Locality Verbose
need = zomato_df['Locality Verbose'].value_counts().index[:10]
zomato_df['Locality Verbose'] = np.where(zomato_df['Locality Verbose'].isin(need), zomato_df['Locality Verbose'], 'OTHER')
valCount = zomato_df['Locality Verbose'].value_counts()
print (valCount)
# Out:
# OTHER                             8664
# Connaught Place, New Delhi         122
# Rajouri Garden, New Delhi           99
# Shahdara, New Delhi                 87
# Defence Colony, New Delhi           86
# Pitampura, New Delhi                85
# Malviya Nagar, New Delhi            84
# Mayur Vihar Phase 1, New Delhi      84
# Rajinder Nagar, New Delhi           81
# Safdarjung, New Delhi               80
# Satyaniketan, New Delhi             79
# Name: Locality Verbose, dtype: int64

# %%
# Two categorical columns can be dropped address and Switch to order menu
zomato_df.drop(['Address','Switch to order menu'], axis = 1, inplace = True)

# %%
zomato_df.sample()
# Out:
#       Country Code    Country  Restaurant ID Restaurant Name   City Locality  \
# 8942           191  Sri Lanka        5800612           OTHER  OTHER    OTHER
#
#      Locality Verbose  Longitude  Latitude   Cuisines  Average Cost for two  \
# 8942            OTHER  79.850748  6.923933  Fast Food                  1000
#
#                    Currency Has Table booking Has Online delivery  \
# 8942  Sri Lankan Rupee(LKR)                No                  No
#
#      Is delivering now  Price range  Aggregate rating Rating color  \
# 8942                No            2               4.1        Green
#
#      Rating text  Votes
# 8942   Very Good    199

# %% [markdown]
# ##### Checking for null values

# %%
zomato_df.isnull().sum()
# Out:
# Country Code            0
# Country                 0
# Restaurant ID           0
# Restaurant Name         0
# City                    0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# only 9 rows in Cuisines have nan values, droping all the rows
zomato_df.dropna(axis = 0, inplace = True)
zomato_df.shape
# Out:
# (9542, 20)

# %% [markdown]
# - rows drooped from 9551 to 9542

# %%
zomato_df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# - No null values now in the data

# %%
# Dropping rating color
zomato_df.drop('Rating color', axis = 1, inplace = True)
zomato_df.sample()
# Out:
#       Country Code Country  Restaurant ID Restaurant Name   City Locality  \
# 7614             1   India       18409725           OTHER  Noida    OTHER
#
#      Locality Verbose  Longitude   Latitude  \
# 7614            OTHER  77.385148  28.532802
#
#                                Cuisines  Average Cost for two  \
# 7614  North Indian, Mughlai, Hyderabadi                   400
#
#                 Currency Has Table booking Has Online delivery  \
# 7614  Indian Rupees(Rs.)                No                  No
#
#      Is delivering now  Price range  Aggregate rating Rating text  Votes
# 7614                No            1               3.3     Average     13

# %%
num
# Out:
# Index(['Country Code', 'Restaurant ID', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes'],
#       dtype='object')

# %%
sns.scatterplot(x = 'Average Cost for two', y = 'Votes', data = zomato_df)
# Out:
# <AxesSubplot:xlabel='Average Cost for two', ylabel='Votes'>

# %% [markdown]
# - Votes are very good for low average cost

# %%
# checking vote distribution for price range
sns.scatterplot(x = 'Price range',y = 'Votes', data = zomato_df)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Votes'>

# %%
# Count of each value for price range
print(zomato_df['Price range'].value_counts())
sns.countplot(x = 'Price range', data = zomato_df)
# Out:
# 1    4438
# 2    3113
# 3    1405
# 4     586
# Name: Price range, dtype: int64
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %% [markdown]
# ##### Summary Statistics

# %%
zomato_df.describe(include = 'all').T
# Out:
#                        count unique                 top  freq            mean  \
# Country Code          9542.0    NaN                 NaN   NaN       18.179208
# Country                 9542     15               India  8652             NaN
# Restaurant ID         9542.0    NaN                 NaN   NaN  9043300.519178
# Restaurant Name         9542     11               OTHER  9071             NaN
# City                    9542      6           New Delhi  5473             NaN
# Locality                9542     11               OTHER  8654             NaN
# Locality Verbose        9542     11               OTHER  8655             NaN
# Longitude             9542.0    NaN                 NaN   NaN       64.274997
# Latitude              9542.0    NaN                 NaN   NaN       25.848532
# Cuisines                9542   1825        North Indian   936             NaN
# Average Cost for two  9542.0    NaN                 NaN   NaN     1200.326137
# ...

# %% [markdown]
# ##### Checking for Outliers

# %%
zomato_df.plot(kind='box', subplots = True, layout = (1,6), figsize = (8,3), fontsize = 8)
# Out:
# Longitude                  AxesSubplot(0.125,0.125;0.110714x0.755)
# Latitude                AxesSubplot(0.257857,0.125;0.110714x0.755)
# Average Cost for two    AxesSubplot(0.390714,0.125;0.110714x0.755)
# Price range             AxesSubplot(0.523571,0.125;0.110714x0.755)
# Aggregate rating        AxesSubplot(0.656429,0.125;0.110714x0.755)
# Votes                   AxesSubplot(0.789286,0.125;0.110714x0.755)
# dtype: object

# %%
# Dropping country code and restaurant ID
zomato_df.drop(['Country Code','Restaurant ID'], axis = 1, inplace = True)
zomato_df.sample()
# Out:
#      Country Restaurant Name       City Locality Locality Verbose  Longitude  \
# 3366   India           OTHER  New Delhi    OTHER            OTHER  77.194159
#
#        Latitude              Cuisines  Average Cost for two  \
# 3366  28.554131  Continental, Italian                  2400
#
#                 Currency Has Table booking Has Online delivery  \
# 3366  Indian Rupees(Rs.)                No                  No
#
#      Is delivering now  Price range  Aggregate rating Rating text  Votes
# 3366                No            4               3.5        Good    884

# %% [markdown]
# ##### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in zomato_df.select_dtypes(include=['object']).columns:
    zomato_df[i]=le.fit_transform(zomato_df[i])

# %%
zomato_df.head()
# Out:
#    Country  Restaurant Name  City  Locality  Locality Verbose  Longitude  \
# 0        3                8     5         4                 4  78.011544
# 1        3                8     5         4                 4   0.000000
# 2        3                8     5         4                 4  78.011608
# 3        3                8     5         4                 4  77.998092
# 4        3                8     5         4                 4  78.007553
#
#     Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  27.161661      1514                   850         4                  0
# 1   0.000000      1514                   700         4                  0
# 2  27.160832      1306                   500         4                  0
# 3  27.195928      1645                   400         4                  0
# 4  27.201725      1373                  1000         4                  0
#
#    Has Online delivery  Is delivering now  Price range  Aggregate rating  \
# ...

# %%
# checking outliers 
from scipy.stats import zscore
z = np.abs(zscore(zomato_df))
z
# Out:
#        Country  Restaurant Name      City  Locality  Locality Verbose  \
# 0     0.276017         0.163368  1.683266   0.07703          0.077243
# 1     0.276017         0.163368  1.683266   0.07703          0.077243
# 2     0.276017         0.163368  1.683266   0.07703          0.077243
# 3     0.276017         0.163368  1.683266   0.07703          0.077243
# 4     0.276017         0.163368  1.683266   0.07703          0.077243
# ...        ...              ...       ...       ...               ...
# 9546  3.899719         0.163368  1.683266   0.07703          0.077243
# 9547  3.899719         0.163368  1.683266   0.07703          0.077243
# 9548  3.899719         0.163368  1.683266   0.07703          0.077243
# 9549  3.899719         0.163368  1.683266   0.07703          0.077243
# 9550  3.899719         0.163368  1.683266   0.07703          0.077243
#
#       Longitude  Latitude  Cuisines  Average Cost for two  Currency  \
# ...

# %%
# List of array containing z-score greater than 3
np.where(z>3)
# Out:
# (array([  20,   85,  102, ..., 9540, 9541, 9541], dtype=int64),
#  array([16,  1, 16, ...,  5,  0,  5], dtype=int64))

# %%
z.shape
# Out:
# (9542, 17)

# %%
# Removing the rows with z score greater than 3
zomato_df_new = zomato_df[(z<3).all(axis=1)]
zomato_df_new
# Out:
#       Country  Restaurant Name  City  Locality  Locality Verbose   Longitude  \
# 0           3                8     5         4                 4   78.011544
# 1           3                8     5         4                 4    0.000000
# 2           3                8     5         4                 4   78.011608
# 3           3                8     5         4                 4   77.998092
# 4           3                8     5         4                 4   78.007553
# ...       ...              ...   ...       ...               ...         ...
# 8858        8                8     5         4                 4  103.858430
# 8859        8                8     5         4                 4  103.839165
# 8860        8                8     5         4                 4  103.858181
# 8861        8                8     5         4                 4  103.848254
# 8862        8                8     5         4                 4  103.851994
#
# ...

# %%
# Checking the shape of the dataset before and after removing outliers
print("Old DataFrame:-", zomato_df.shape)
print("New DataFrame:-", zomato_df_new.shape)
print('Total dropped rows:-', zomato_df.shape[0]-zomato_df_new.shape[0])
# Out:
# Old DataFrame:- (9542, 17)
# New DataFrame:- (7683, 17)
# Total dropped rows:- 1859

# %%
# Percentage loss of data
loss_percent = (9542 - 7683)/7683*100
print(loss_percent,'%')
# Out:
# 24.196277495769884 %

# %% [markdown]
# - Loss of data will be too much, hence we will not remove the outliers

# %% [markdown]
# ##### Splitting the data into X & Y for both cases

# %% [markdown]
# ###### Case 1 - Average Cost for two (Regression Problem)

# %%
X1 = zomato_df.drop('Average Cost for two', axis = 1)
y1 = zomato_df['Average Cost for two']

# %%
X1.shape, y1.shape
# Out:
# ((9542, 16), (9542,))

# %% [markdown]
# ###### Case 2 - Price range (Classification Problem)

# %%
X2 = zomato_df.drop('Price range', axis = 1)
y2 = zomato_df['Price range']

# %%
X2.shape, y2.shape
# Out:
# ((9542, 16), (9542,))

# %% [markdown]
# ##### Checking for skewness

# %%
X1.skew()
# Out:
# Country                 3.337828
# Restaurant Name        -5.509840
# City                   -0.189740
# Locality                2.066244
# Locality Verbose        2.067687
# Longitude              -2.819828
# Latitude               -3.081780
# Cuisines               -0.305923
# Currency                2.879234
# Has Table booking       2.319457
# Has Online delivery     1.113168
# Is delivering now      16.665472
# Price range             0.889879
# Aggregate rating       -0.953052
# Rating text             0.430970
# Votes                   8.813270
# dtype: float64

# %%
# Let's plot distribution plot
X1.plot(kind='density', subplots = True, layout = (4,6), sharex = False, legend= False, fontsize =1, figsize = (18,12))
plt.show()

# %%
# Lets remove the skewness using transformation for regression
for index in X1.skew().index:
    if X1.skew().loc[index]>0:
        X1[index]=np.log1p(X1[index])
    if X1.skew().loc[index]<0:
        X1[index]=np.square(X1[index])

# %%
# After removing the skewness
X1.skew()
# Out:
# Country                 2.649883
# Restaurant Name        -4.289499
# City                    0.949721
# Locality                1.022464
# Locality Verbose        1.023840
# Longitude               4.066515
# Latitude                1.767648
# Cuisines                0.257580
# Currency                1.398436
# Has Table booking       2.319457
# Has Online delivery     1.113168
# Is delivering now      16.665472
# Price range             0.496085
# Aggregate rating       -0.208199
# Rating text             0.488425
# Votes                   1.048883
# dtype: float64

# %%
# skewness for classification problem
X2.skew()
# Out:
# Country                  3.337828
# Restaurant Name         -5.509840
# City                    -0.189740
# Locality                 2.066244
# Locality Verbose         2.067687
# Longitude               -2.819828
# Latitude                -3.081780
# Cuisines                -0.305923
# Average Cost for two    35.461264
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Aggregate rating        -0.953052
# Rating text              0.430970
# Votes                    8.813270
# dtype: float64

# %%
# Lets remove the skewness using transformation for classification
for index in X2.skew().index:
    if X2.skew().loc[index]>0:
        X2[index]=np.log1p(X2[index])
    if X2.skew().loc[index]<0:
        X2[index]=np.square(X2[index])

# %%
# After removing the skewness
X2.skew()
# Out:
# Country                  2.649883
# Restaurant Name         -4.289499
# City                     0.949721
# Locality                 1.022464
# Locality Verbose         1.023840
# Longitude                4.066515
# Latitude                 1.767648
# Cuisines                 0.257580
# Average Cost for two     1.663725
# Currency                 1.398436
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Aggregate rating        -0.208199
# Rating text              0.488425
# Votes                    1.048883
# dtype: float64

# %% [markdown]
# ##### Correlation

# %%
zomato_df.corr()
# Out:
#                        Country  Restaurant Name      City  Locality  \
# Country               1.000000         0.042532  0.464609 -0.021262
# Restaurant Name       0.042532         1.000000  0.014042  0.004322
# City                  0.464609         0.014042  1.000000 -0.018579
# Locality             -0.021262         0.004322 -0.018579  1.000000
# Locality Verbose     -0.021320         0.004356 -0.018250  0.999814
# Longitude            -0.763055        -0.038381 -0.374163  0.007282
# Latitude              0.180572        -0.013565 -0.203914 -0.003531
# Cuisines             -0.131155        -0.030219 -0.076431  0.001671
# Average Cost for two -0.003793         0.005989  0.062137 -0.005676
# Currency             -0.098312        -0.002837 -0.037693  0.001725
# Has Table booking    -0.061157         0.058092 -0.064707 -0.066988
# Has Online delivery  -0.139329         0.070074 -0.122793 -0.039192
# Is delivering now    -0.016506         0.009769 -0.022569 -0.006262
# ...

# %%
plt.figure(figsize = (12,10))
sns.heatmap(zomato_df.corr(), annot = True, fmt ="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Model Building

# %% [markdown]
# ##### Case 1  - Regression - Average cost of two

# %% [markdown]
# ##### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mms_z1 = MinMaxScaler()
X1 = mms_z1.fit_transform(X1)
X1
# Out:
# array([[0.51191605, 0.64      , 1.        , ..., 0.63348605, 0.37594948,
#         0.28317353],
#        [0.51191605, 0.64      , 1.        , ..., 0.51020408, 0.37594948,
#         0.21148062],
#        [0.51191605, 0.64      , 1.        , ..., 0.53977509, 0.37594948,
#         0.23978525],
#        ...,
#        [1.        , 0.64      , 1.        , ..., 0.63348605, 0.37594948,
#         0.29560804],
#        [1.        , 0.64      , 1.        , ..., 0.63348605, 0.37594948,
#         0.29560804],
#        [1.        , 0.64      , 1.        , ..., 0.42648896, 0.        ,
#         0.09281506]])

# %%
# Importing the libraries for model building
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %%
# Instantiating each algorithm
lr = LinearRegression()
dtr = DecisionTreeRegressor()
knr = KNeighborsRegressor()
svr = SVR()
rfr = RandomForestRegressor()

# List of instantiated algorithms
model = [lr, dtr, knr, svr, rfr]

# %%
# Maximum accuracy
maxAccu = 0 

# Best random state value for which accuracy is achieved 
maxRS = 0

for m in model:
    for i in range(0,70):
        x_train, x_test,y_train, y_test = train_test_split(X1,y1, random_state=i, test_size=0.20)
        m.fit(x_train, y_train)
        pred_train= m.predict(x_train)
        pred_test = m.predict(x_test)
        score_train = m.score(x_train, y_train)
        score_test = m.score(x_test, y_test)
        r2 = r2_score(y_test, pred_test)
        print(f'----------------At random State {i} ------------------')
        print(f"Training score is {score_train}")
        print(f"Testing score is {score_test}")
        print(f'r2 score of {m} is {r2}')
    
        if r2 > maxAccu:
            maxAccu = r2
            maxRS = i
            print(f"Maximum score of {m} is {maxAccu} at Random state {i}")
            print('\n')
    print('*'*120)
# Out:
# ----------------At random State 0 ------------------
# Training score is 0.04308240937632124
# Testing score is 0.032843315232536585
# r2 score of LinearRegression() is 0.032843315232536585
# Maximum score of LinearRegression() is 0.032843315232536585 at Random state 0
#
#
# ----------------At random State 1 ------------------
# Training score is 0.04354956311444402
# Testing score is 0.031170273554327776
# r2 score of LinearRegression() is 0.031170273554327776
# ----------------At random State 2 ------------------
# Training score is 0.033609853485435215
# Testing score is 0.04112438461310375
# r2 score of LinearRegression() is 0.04112438461310375
# Maximum score of LinearRegression() is 0.04112438461310375 at Random state 2
#
#
# ----------------At random State 3 ------------------
# Training score is 0.045809549817682704
# Testing score is -0.5921121238314524
# r2 score of LinearRegression() is -0.5921121238314524
# ----------------At random State 4 ------------------
# ...

# %% [markdown]
# - Maximum score of KNeighborsRegressor() is 0.9215567907432602 at Random state 31
# - Maximum score of RandomForestRegressor() is 0.9293694861954764 at Random state 12

# %% [markdown]
# ##### Cross validation of all the Algorithms for regression

# %%
# Before proceeding with the hpyer parameter tunning we will check for cross validation
from sklearn.model_selection import cross_val_score
max_cvscore = 0 
max_cv = 0
for m in model:
    print(f'---------------------- Cross Validation of {m} --------------------------')
    for j in range(2,5):
        cv_score = cross_val_score(m, X2,y2,cv=j)
        cv_mean = cv_score.mean()
        print(f"At cross fold {j} the cv score is {cv_mean}")
        print('\n') 
    
        if cv_mean > max_cvscore:
            max_cvscore=cv_mean
            max_cv = j
            print(f"At cross fold {j} the Maximum CV score is {max_cvscore}")
            print('\n') 
    print('*'*120)
    print('\n')
# Out:
# ---------------------- Cross Validation of LinearRegression() --------------------------
# At cross fold 2 the cv score is 0.04491037316947666
#
#
# At cross fold 2 the Maximum CV score is 0.04491037316947666
#
#
# At cross fold 3 the cv score is 0.12877893485370215
#
#
# At cross fold 3 the Maximum CV score is 0.12877893485370215
#
#
# At cross fold 4 the cv score is 0.14923159672796615
#
#
# At cross fold 4 the Maximum CV score is 0.14923159672796615
#
#
# ************************************************************************************************************************
#
#
# ---------------------- Cross Validation of DecisionTreeRegressor() --------------------------
# At cross fold 2 the cv score is 0.6326845052857915
#
#
# At cross fold 2 the Maximum CV score is 0.6326845052857915
#
#
# At cross fold 3 the cv score is 0.6734820544266413
#
#
# At cross fold 3 the Maximum CV score is 0.6734820544266413
#
#
# At cross fold 4 the cv score is 0.6754649584676511
#
#
# ...

# %% [markdown]
# - At cross fold 3 the Maximum CV score is 0.6886145893642581
# - When I compare Kneighbour regressor and Random forest cross validation of RF is better

# %%
# Training Random forest Regressor at Random state 12
x_train, x_test,y_train, y_test = train_test_split(X1,y1, random_state=12, test_size=0.20)
rfr.fit(x_train, y_train)
pred_train= rfr.predict(x_train)
pred_test = rfr.predict(x_test)
score_train = rfr.score(x_train, y_train)
score_test = rfr.score(x_test, y_test)
r2 = r2_score(y_test, pred_test)
print(f"Training score is {score_train}")
print(f"Testing score is {score_test}")
print(f'r2 score of {rfr} is {r2}')
# Out:
# Training score is 0.9078660068131706
# Testing score is 0.9328438610998575
# r2 score of RandomForestRegressor() is 0.9328438610998575

# %% [markdown]
# ##### Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV
param = {'n_estimators':[100],'max_depth': [2,4],'criterion': ['mse','mae'],'max_features':['sqrt','log2']}

gcv1 = GridSearchCV(rfr,param,cv=3,scoring= 'accuracy')

# training
gcv1.fit(x_train, y_train)

# Getting the best parameters
print("Best parameters:", gcv1.best_params_)

print("Best Estimator:",gcv1.best_estimator_)

gcv_pred=gcv1.best_estimator_.predict(x_test)

print('Final Accuracy with Random Forest Regression:', r2_score(y_test,gcv_pred))
# Out:
# Best parameters: {'criterion': 'mse', 'max_depth': 2, 'max_features': 'sqrt', 'n_estimators': 100}
# Best Estimator: RandomForestRegressor(max_depth=2, max_features='sqrt')
# Final Accuracy with Random Forest Regression: 0.7067224940813592

# %% [markdown]
# #### Pickling Regression Model

# %%
# Pickling of the file or serialization of a file
import joblib
joblib.dump(gcv1.best_estimator_,"Zomato_regression.pkl")
# Out:
# ['Zomato_regression.pkl']

# %%
zomato_model_regression = joblib.load('Zomato_regression.pkl')
zomato_result_regression = zomato_model_regression.score(x_test, y_test)
print(zomato_result_regression*100)
# Out:
# 70.67224940813593

# %%
zomato_conclusion_regression = pd.DataFrame([zomato_model_regression.predict(x_test),y_test], index=['Predicted Average cost for two', 'Original Average cost for two'])
zomato_conclusion_regression.T
# Out:
#       Predicted Average cost for two  Original Average cost for two
# 0                         998.680629                         1500.0
# 1                         521.638117                          350.0
# 2                         523.728297                          500.0
# 3                         904.879460                         1500.0
# 4                        1037.498442                         3500.0
# ...                              ...                            ...
# 1904                      850.870154                           80.0
# 1905                      512.280567                          150.0
# 1906                      701.462755                          900.0
# 1907                     6105.739210                           20.0
# 1908                      514.977425                          200.0
#
# [1909 rows x 2 columns]

# %%
sns.regplot(x = 'Predicted Average cost for two', y = 'Original Average cost for two', data = zomato_conclusion_regression.T)
# Out:
# <AxesSubplot:xlabel='Predicted Average cost for two', ylabel='Original Average cost for two'>

# %% [markdown]
# - The above result shown is after tunning

# %%
# Pickling the model without being tunned
joblib.dump(rfr,"Zomato_regression1.pkl")
# Out:
# ['Zomato_regression1.pkl']

# %%
zomato_model_regression1 = joblib.load('Zomato_regression1.pkl')
zomato_result_regression1 = zomato_model_regression1.score(x_test, y_test)
print(zomato_result_regression1*100)
# Out:
# 93.28438610998575

# %%
zomato_conclusion_regression1 = pd.DataFrame([zomato_model_regression1.predict(x_test),y_test], index=['Predicted Average cost for two1', 'Original Average cost for two1'])
zomato_conclusion_regression1.T
# Out:
#       Predicted Average cost for two1  Original Average cost for two1
# 0                              1227.5                          1500.0
# 1                               293.5                           350.0
# 2                               583.0                           500.0
# 3                              1297.5                          1500.0
# 4                              2960.5                          3500.0
# ...                               ...                             ...
# 1904                             76.9                            80.0
# 1905                            205.5                           150.0
# 1906                            809.5                           900.0
# 1907                             20.0                            20.0
# 1908                            228.0                           200.0
#
# [1909 rows x 2 columns]

# %%
sns.regplot(x = 'Predicted Average cost for two1', y = 'Original Average cost for two1', data = zomato_conclusion_regression1.T)
# Out:
# <AxesSubplot:xlabel='Predicted Average cost for two1', ylabel='Original Average cost for two1'>

# %% [markdown]
# - One can see that the model without tunning is performing better

# %% [markdown]
# ##### Case 1 - Classification - Price range

# %% [markdown]
# ##### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
mms_z2 = MinMaxScaler()
X2 = mms_z2.fit_transform(X2)
X2
# Out:
# array([[0.51191605, 0.64      , 1.        , ..., 0.63348605, 0.37594948,
#         0.28317353],
#        [0.51191605, 0.64      , 1.        , ..., 0.51020408, 0.37594948,
#         0.21148062],
#        [0.51191605, 0.64      , 1.        , ..., 0.53977509, 0.37594948,
#         0.23978525],
#        ...,
#        [1.        , 0.64      , 1.        , ..., 0.63348605, 0.37594948,
#         0.29560804],
#        [1.        , 0.64      , 1.        , ..., 0.63348605, 0.37594948,
#         0.29560804],
#        [1.        , 0.64      , 1.        , ..., 0.42648896, 0.        ,
#         0.09281506]])

# %%
# Importing the model libraries
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lg = LogisticRegression()
gnb = GaussianNB()
dtc = DecisionTreeClassifier()
knn = KNeighborsClassifier()
rfc = RandomForestClassifier()

model = [lg, gnb, dtc, knn, rfc]

# %%
# Maximum accuracy
maxAccu = 0 

# Best random state value for which accuracy is achieved 
maxRS = 0
for m in model:
    for i in range(0,50):
        x_train, x_test, y_train, y_test= train_test_split(X2,y2,test_size= 0.2, random_state=i)
        m.fit(x_train, y_train)
        train_score = m.score(x_train, y_train)
        test_score = m.score(x_train, y_train)
        pred = m.predict(x_test)
        print(f'----------------At random State {i} ------------------')
        acc = accuracy_score(y_test, pred)
        print("Accuracy score of ", m, 'is:', acc)
        print(f'Training score of {m} is {train_score}')
        print(f'Testing score of {m} is {test_score}')
        print('\n')
    
        if acc > maxAccu:
            maxAccu = acc
            maxRS = i
            print(f"Maximum accuracy score of {m} is {acc} at Random state {i}")
            print('\n')
    print('*'*120)
# Out:
# ----------------At random State 0 ------------------
# Accuracy score of  LogisticRegression() is: 0.7218438973284442
# Training score of LogisticRegression() is 0.7297261889165466
# Testing score of LogisticRegression() is 0.7297261889165466
#
#
# Maximum accuracy score of LogisticRegression() is 0.7218438973284442 at Random state 0
#
#
# ----------------At random State 1 ------------------
# Accuracy score of  LogisticRegression() is: 0.7427972760607648
# Training score of LogisticRegression() is 0.7303812393554304
# Testing score of LogisticRegression() is 0.7303812393554304
#
#
# Maximum accuracy score of LogisticRegression() is 0.7427972760607648 at Random state 1
#
#
# ----------------At random State 2 ------------------
# Accuracy score of  LogisticRegression() is: 0.7344159245678366
# Training score of LogisticRegression() is 0.7297261889165466
# Testing score of LogisticRegression() is 0.7297261889165466
#
#
# ----------------At random State 3 ------------------
# ...

# %% [markdown]
# - Maximum accuracy score of DecisionTreeClassifier() is 0.9842849659507595 at Random state 14

# %% [markdown]
# ##### Cross validation of all the Algorithms

# %%
# Before proceeding with the hpyer parameter tunning we will check for cross validation
from sklearn.model_selection import cross_val_score
max_cvscore = 0 
max_cv = 0
for m in model:
    print(f'---------------------- Cross Validation of {m} --------------------------')
    for j in range(2,8):
        cv_score = cross_val_score(m, X2, y2,cv=j)
        cv_mean = cv_score.mean()
        print(f"At cross fold {j} the cv score is {cv_mean}")
        print('\n') 
    
        if cv_mean > max_cvscore:
            max_cvscore=cv_mean
            max_cv = j
            print(f"At cross fold {j} the Maximum CV score is {max_cvscore}")
            print('\n') 
    print('*'*120)
    print('\n')
# Out:
# ---------------------- Cross Validation of LogisticRegression() --------------------------
# At cross fold 2 the cv score is 0.6717669251729197
#
#
# At cross fold 2 the Maximum CV score is 0.6717669251729197
#
#
# At cross fold 3 the cv score is 0.6784708670519469
#
#
# At cross fold 3 the Maximum CV score is 0.6784708670519469
#
#
# At cross fold 4 the cv score is 0.6760632867126722
#
#
# At cross fold 5 the cv score is 0.6807813699424441
#
#
# At cross fold 5 the Maximum CV score is 0.6807813699424441
#
#
# At cross fold 6 the cv score is 0.6865463093633344
#
#
# At cross fold 6 the Maximum CV score is 0.6865463093633344
#
#
# At cross fold 7 the cv score is 0.6971314724137009
#
#
# At cross fold 7 the Maximum CV score is 0.6971314724137009
#
#
# ************************************************************************************************************************
#
#
# ---------------------- Cross Validation of GaussianNB() --------------------------
# ...

# %% [markdown]
# - At cross fold 7 the Maximum CV score is 0.9324020948639318 for Decisioon Tree Classifier

# %%
for m in model:
    x_train, x_test, y_train, y_test= train_test_split(X2,y2,test_size= 0.2, random_state=14)
    m.fit(x_train, y_train)
    train_score = m.score(x_train, y_train)
    test_score = m.score(x_train, y_train)
    pred = m.predict(x_test)
    print(f'--------------------- {m} ----------------------')
    acc_hr = accuracy_score(y_test, pred)
    print("Accuracy score of ", m, 'is:', acc)
    print(f'Training score of {m} is {train_score}')
    print(f'Testing score of {m} is {test_score}')
    print("Confusion Matrix:\n",confusion_matrix(y_test, pred))
    print('Classification Report:\n',classification_report(y_test, pred))
    print('*'*120,'\n')
# Out:
# --------------------- LogisticRegression() ----------------------
# Accuracy score of  LogisticRegression() is: 0.9800942902042954
# Training score of LogisticRegression() is 0.732739420935412
# Testing score of LogisticRegression() is 0.732739420935412
# Confusion Matrix:
#  [[794  82   8   0]
#  [150 385  77   2]
#  [ 21 101 162   6]
#  [  8  19  87   7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.82      0.90      0.86       884
#            2       0.66      0.63      0.64       614
#            3       0.49      0.56      0.52       290
#            4       0.47      0.06      0.10       121
#
#     accuracy                           0.71      1909
#    macro avg       0.61      0.54      0.53      1909
# weighted avg       0.69      0.71      0.69      1909
#
# ************************************************************************************************************************
#
# ...

# %% [markdown]
# - We can see that Decision Tree Classifier is predicted well and also the random forest classifier

# %% [markdown]
# ##### Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV
param_dtc = {'max_depth': [2, 3, 5, 10, 20],'min_samples_leaf': [5, 10, 20, 50, 100],'criterion': ["gini", "entropy"]}

gcv_dtc = GridSearchCV(dtc,param_dtc,cv=8,scoring= 'accuracy')

# training
gcv_dtc.fit(x_train, y_train)

# Getting the best parameters
print("Best parameters:", gcv_dtc.best_params_)

print("Best Estimator:",gcv_dtc.best_estimator_)

gcv_dtc_pred=gcv_dtc.best_estimator_.predict(x_test)

print('Final Accuracy with Decision Tree Classifier:', accuracy_score(y_test,gcv_dtc_pred))
# Out:
# Best parameters: {'criterion': 'gini', 'max_depth': 10, 'min_samples_leaf': 5}
# Best Estimator: DecisionTreeClassifier(max_depth=10, min_samples_leaf=5)
# Final Accuracy with Decision Tree Classifier: 0.9806181246726035

# %% [markdown]
# ### Pickling

# %%
# Pickling of the file or serialization of a file
# Random Forest Classifier
import joblib
joblib.dump(gcv_dtc.best_estimator_,"Zomato_classification.pkl")
# Out:
# ['Zomato_classification.pkl']

# %%
zomato_model_dtc = joblib.load('Zomato_classification.pkl')
zomato_result_dtc = zomato_model_dtc.score(x_test, y_test)
print(zomato_result_dtc*100)
# Out:
# 98.06181246726034

# %%
zomato_conclusion_dtc = pd.DataFrame([zomato_model_dtc.predict(x_test),y_test], index=['Predicted Price Range', 'Original Price Range'])
zomato_conclusion_dtc.T
# Out:
#       Predicted Price Range  Original Price Range
# 0                         2                     2
# 1                         2                     2
# 2                         2                     2
# 3                         2                     2
# 4                         1                     1
# ...                     ...                   ...
# 1904                      3                     3
# 1905                      2                     2
# 1906                      1                     1
# 1907                      1                     1
# 1908                      2                     2
#
# [1909 rows x 2 columns]

# %%
sns.barplot(x = 'Predicted Price Range', y = 'Original Price Range', data = zomato_conclusion_dtc.T)
# Out:
# <AxesSubplot:xlabel='Predicted Price Range', ylabel='Original Price Range'>

# %% [markdown]
# - Model is predicted very well for the price range with Decision Tree Classifier

# %% [markdown]
# ###### Thank You
