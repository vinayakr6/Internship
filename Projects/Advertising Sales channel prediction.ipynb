# %% [markdown]
# ##### Advertising Sales Channel Prediction - Vinayak Ratan

# %% [markdown]
# Problem Statement:
# Sales Channel Prediction Case Study
#
# When a company enters a market, the distribution strategy and channel it uses are keys to its success in the market, as well as market know-how and customer knowledge and understanding. Because an effective distribution strategy under efficient supply-chain management opens doors for attaining competitive advantage and strong brand equity in the market, it is a component of the marketing mix that cannot be ignored .
#
# The distribution strategy and the channel design have to be right the first time. The case study of Sales channel includes the detailed study of TV, radio and newspaper channel. The predict the total sales

# %%
# Importing the libraries
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
ad_df = pd.read_csv(r'G:\AI Professional\Data Trained\Notes\Github docs\Datasets\DSData-master\Advertising.csv', index_col = 'Unnamed: 0')
ad_df
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
ad_df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
ad_df.tail()
# Out:
#         TV  radio  newspaper  sales
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4

# %%
ad_df.sample()
# Out:
#      TV  radio  newspaper  sales
# 3  17.2   45.9       69.3    9.3

# %%
ad_df.shape
# Out:
# (200, 4)

# %%
# type of dataset
type(ad_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Checking the datatypes 
ad_df.dtypes
# Out:
# TV           float64
# radio        float64
# newspaper    float64
# sales        float64
# dtype: object

# %% [markdown]
# - All the columns are of float data type

# %% [markdown]
# #### Checking for null values

# %%
ad_df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# - There are no null values present in the dataset

# %%
# plotting the heatmap for the null values
sns.heatmap(ad_df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# ##### Data Visualization

# %%
ad_df.columns
# Out:
# Index(['TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
columns = ['TV', 'radio', 'newspaper', 'sales']
columns
# Out:
# ['TV', 'radio', 'newspaper', 'sales']

# %%
for i in columns[0:3]:
    ad_df.plot(x = 'sales', y = i, kind = 'scatter', subplots = True, layout = (2,2), figsize = (10,10))
    plt.show()

# %%
plt.figure(figsize=(10,8))
plot_no = 1
for j in columns:
    if plot_no <= 3:
        ax = plt.subplot(2,2,plot_no)
        sns.regplot(x='sales', y= j, data = ad_df )
    plot_no += 1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# - Observations
#     - Both from scatter plot and regression plot we can observe that the sales are continuously increasing for TV and radio
#     - Also, for newspaper sales are increasing, but very gradually

# %%
plt.figure(figsize=(10,8))
plot_no = 1
for k in columns:
    if plot_no <= 4:
        ax = plt.subplot(2,2,plot_no)
        sns.histplot(x = k, data = ad_df, kde = True )
    plot_no += 1
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# - Observations
#     - In sales of TV and radio one can see the bimodal distribution in the data
#     - In case of newspaper sales the data is right skewed
#     - total sales is almost normally distributed

# %%
ad_df.plot(kind='box', subplots = True, layout = (2,2), figsize = (20,12), title = "Box Plot to check outliers", fontsize = 13)
# Out:
# TV              AxesSubplot(0.125,0.536818;0.352273x0.343182)
# radio        AxesSubplot(0.547727,0.536818;0.352273x0.343182)
# newspaper          AxesSubplot(0.125,0.125;0.352273x0.343182)
# sales           AxesSubplot(0.547727,0.125;0.352273x0.343182)
# dtype: object

# %% [markdown]
# - Few outliers are present in the newspaper sales
# - based on the maximum values, maximum sales are in TV followed by newspaper then radio

# %% [markdown]
# #### Correlation

# %%
ad_df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(ad_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Observations
#     - We can clearly see that TV is highly correlated with sales, then next radio which is also highly correlated and then newspaper which is less correlated compared with others.
#     - radio and newspaper have a correlation of 0.35, showing the presence of multicollinearity. Hence we need to check for VIF.

# %% [markdown]
# #### Summary Statistics

# %%
ad_df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# - ##### Observations
#     ###### TV
#     - Mean: 147.04
#     - Standard deviation: 85.85
#     - Median: 149.75
#     ###### radio
#     - Mean: 23.26
#     - Standard deviation: 14.84
#     - Median: 22.9
#     ###### newspaper
#     - Mean: 30.55
#     - Standard deviation: 21.77
#     - Median: 25.75
#     ###### total sales
#     - Mean: 14.02
#     - Standard deviation: 5.217
#     - Median: 12.9

# %%
plt.figure(figsize = (8,4))
sns.heatmap(ad_df.describe(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### skewness

# %%
ad_df.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.894720
# sales        0.407571
# dtype: float64

# %%
plt.figure(figsize=(12,3))
plot_no = 1
for column in ad_df:
    if plot_no <= 4:
        ax = plt.subplot(1,4,plot_no)
        sns.distplot(ad_df[column])
        plt.xlabel(column, fontsize = 15)

    plot_no += 1
plt.tight_layout()

# %% [markdown]
# - There is skewness present in newspaper sales
# - TV and radio sales show bimodal distribution

# %%
# Removing skewness
ad_df['newspaper'] = np.sqrt(ad_df['newspaper'])

# %%
ad_df.skew()
# Out:
# TV          -0.069853
# radio        0.094175
# newspaper    0.062388
# sales        0.407571
# dtype: float64

# %%
# Distribution Plot after removing skewness
plt.figure(figsize=(12,3))
plot_no = 1
for column in ad_df:
    if plot_no <= 4:
        ax = plt.subplot(1,4,plot_no)
        sns.distplot(ad_df[column])
        plt.xlabel(column, fontsize = 15)

    plot_no += 1
plt.tight_layout()

# %% [markdown]
# - Skewness removed from newspaper sales data

# %%
# Histogram Plot after removing skewness
plt.figure(figsize=(12,3))
plot_no = 1
for column in ad_df:
    if plot_no <= 4:
        ax = plt.subplot(1,4,plot_no)
        sns.histplot(ad_df[column])
        plt.xlabel(column, fontsize = 15)

    plot_no += 1
plt.tight_layout()

# %% [markdown]
# ##### Outliers

# %%
from scipy.stats import zscore
z_ad= np.abs(zscore(ad_df))
z_ad
# Out:
#            TV     radio  newspaper     sales
# 1    0.969852  0.981522   1.563095  1.552053
# 2    1.197376  1.082808   0.774855  0.696046
# 3    1.516155  1.528463   1.566049  0.907406
# 4    0.052050  1.217855   1.233576  0.860330
# 5    0.394182  0.841614   1.230360  0.215683
# ..        ...       ...        ...       ...
# 196  1.270941  1.321031   0.700730  1.234053
# 197  0.617035  1.240003   1.127935  0.830548
# 198  0.349810  0.942899   1.283433  0.234898
# 199  1.594565  1.265121   1.473445  2.205347
# 200  0.993206  0.990165   1.077029  0.119610
#
# [200 rows x 4 columns]

# %%
# data with zscore greater than 3
np.where(z_ad>3)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# - There is no data with zscore more than 3

# %% [markdown]
# #### Feature Engineering

# %%
# Spliting the data in x (features) and y(target) 
X = ad_df.iloc[:,:-1]
X.head(2)
# Out:
#       TV  radio  newspaper
# 1  230.1   37.8   8.318654
# 2   44.5   39.3   6.715653

# %%
y = ad_df.iloc[:,-1]
y.head(2)
# Out:
# 1    22.1
# 2    10.4
# Name: sales, dtype: float64

# %%
X.shape
# Out:
# (200, 3)

# %%
y.shape
# Out:
# (200,)

# %%
##### Variance Inflation factor
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif_calc():
    vif_ad=pd.DataFrame()
    vif_ad['VIF_Factor']= [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif_ad['features names']=X.columns
    print(vif_ad)

# %%
vif_calc()
# Out:
#    VIF_Factor features names
# 0    3.036296             TV
# 1    3.645082          radio
# 2    4.781630      newspaper

# %% [markdown]
# - radio and newspaper have high VIF
# - from out of the two radio and newspaper from correlation matrix newspaper is less correlated with target values. Hence, droping the newspaper

# %%
ad_df.drop(['newspaper'], axis = 1, inplace = True)
ad_df
# Out:
#         TV  radio  sales
# 1    230.1   37.8   22.1
# 2     44.5   39.3   10.4
# 3     17.2   45.9    9.3
# 4    151.5   41.3   18.5
# 5    180.8   10.8   12.9
# ..     ...    ...    ...
# 196   38.2    3.7    7.6
# 197   94.2    4.9    9.7
# 198  177.0    9.3   12.8
# 199  283.6   42.0   25.5
# 200  232.1    8.6   13.4
#
# [200 rows x 3 columns]

# %%
# Splitting the data after feature selection
X = ad_df.iloc[:,:-1]
X.head(2)
# Out:
#       TV  radio
# 1  230.1   37.8
# 2   44.5   39.3

# %%
vif_calc()
# Out:
#    VIF_Factor features names
# 0    2.238085             TV
# 1    2.238085          radio

# %% [markdown]
# ##### Scaling the feature variables using standard scaler

# %%
from sklearn.preprocessing import StandardScaler 
scale = StandardScaler()
X = scale.fit_transform(X)
X
# Out:
# array([[ 0.96985227,  0.98152247],
#        [-1.19737623,  1.08280781],
#        [-1.51615499,  1.52846331],
#        [ 0.05204968,  1.21785493],
#        [ 0.3941822 , -0.84161366],
#        [-1.61540845,  1.73103399],
#        [-1.04557682,  0.64390467],
#        [-0.31343659, -0.24740632],
#        [-1.61657614, -1.42906863],
#        [ 0.61604287, -1.39530685],
#        [-0.94515567, -1.17923146],
#        [ 0.79002835,  0.04969734],
#        [-1.4390876 ,  0.79920886],
#        [-0.57850171, -1.05768905],
#        [ 0.66625345,  0.65065703],
#        [ 0.56466461,  1.65000572],
#        [-0.92530498,  0.9004942 ],
#        [ 1.56887609,  1.10306488],
#        [-0.90895735, -0.18663512],
#        [ 0.0030068 ,  0.04294498],
#        [ 0.8332328 ,  0.29953451],
#        [ 1.05509347, -1.22649795],
#        [-1.5628625 , -0.4972435 ],
#        [ 0.94883389, -0.42971994],
#        [-0.98952781, -0.72007125],
#        [ 1.35285385, -1.33453565],
#        [-0.04837147,  0.40757221],
#        [ 1.08662104, -0.44322465],
#        [ 1.18820988,  0.25902038],
#        [-0.89260972, -0.49049114],
#        [ 1.70316018,  0.34004865],
#        [-0.3986778 , -0.39595816],
#        [-0.58200477, -1.46958277],
#        [ 1.38438142, -0.2203969 ],
#        [-0.59952009, -1.47633512],
#        [ 1.67747105, -1.29402151],
#        [ 1.39956136,  1.38666383],
#        [-0.84473452,  1.76479577],
#        [-1.21372386,  0.23201095],
#        [ 0.94533082,  0.97477012],
#        [ 0.64757044, -0.06509271],
#        [ 0.34981006,  0.68441881],
#        [ 1.711334  ,  0.29953451],
#        [ 0.6989487 , -1.0036702 ],
#        [-1.42390765,  0.16448739],
#        [ 0.327624  , -0.051588  ],
#        [-0.66958136, -0.90238486],
#        [ 1.08428567,  1.23135965],
#        [ 0.93598932, -0.50399585],
#        [-0.93581417, -0.78084245],
#        [ 0.61604287, -1.36154507],
#        [-0.54463877, -0.92264193],
#        [ 0.80987904,  1.24486436],
#        [ 0.41520058,  1.54872038],
#        [ 1.35051848,  0.37381043],
#        [ 0.60553368,  1.76479577],
#        [-1.63175608,  0.32654394],
#        [-0.12660655, -0.27441575],
#        [ 0.74448853,  1.77830048],
#        [ 0.74332084,  0.42107692],
#        [-1.09228433, -1.43582099],
#        [ 1.33417085,  1.31238792],
#        [ 1.07727954, -0.52425292],
#        [-0.51778195,  0.42782928],
#        [-0.18615862,  1.31914027],
#        [-0.91129272, -0.942899  ],
#        [-1.34917564,  0.09021148],
#        [-0.09040823, -0.59177648],
#        [ 1.05509347,  0.2860298 ],
#        [ 0.81454979,  1.39341619],
#        [ 0.60786906,  0.49535284],
#        [-0.43487612, -0.60528119],
#        [-1.40405696,  0.65740938],
#        [-0.20600931, -1.18598381],
#        [ 0.77484841,  0.09021148],
#        [-1.51965805,  1.37991148],
#        [-1.39588315, -1.46283041],
#        [-0.30993353,  0.35355336],
#        [-1.65394214,  0.44808635],
#        [-0.36247947, -1.05093669],
#        [-0.82488383,  0.23201095],
#        [ 1.08311798, -1.29402151],
#        [-0.8377284 , -0.20013983],
#        [-0.91829885,  1.43393033],
#        [ 0.7760161 ,  1.33264499],
#        [ 0.53897548, -0.3284346 ],
#        [-0.82605152,  0.2860298 ],
#        [-0.42436693,  1.17058844],
#        [-0.68592899,  0.15098268],
#        [-0.43487612,  1.65675807],
#        [-0.14879261, -1.24000266],
#        [-1.38303858, -1.46958277],
#        [ 0.82505898,  0.69117116],
#        [ 1.21273132,  0.89374184],
#        [-0.46290062, -0.62553826],
#        [ 0.18983684,  0.5628764 ],
#        [ 0.59035374, -1.33453565],
#        [ 0.4420574 , -0.15287334],
#        [ 1.66579418,  1.28537849],
#        [-0.13828342,  1.24486436],
#        [ 0.87994031, -1.2805168 ],
#        [ 1.74402926,  0.88023713],
#        [ 1.55486384, -0.88888015],
#        [ 0.47708803, -0.40946287],
#        [ 1.06443498,  0.74519001],
#        [-0.10675585,  1.56222509],
#        [-1.42507534, -0.82810894],
#        [-0.66140754, -1.55061104],
#        [-1.56403019, -1.54385868],
#        [ 1.26527727,  0.24551567],
#        [ 0.91964169, -1.01717491],
#        [ 1.10530405,  0.99502718],
#        [ 0.33463012, -0.53100528],
#        [ 0.73047627, -0.17988276],
#        [-0.80386545,  1.58923451],
#        [-0.84006377,  0.7924565 ],
#        [-0.09157591, -0.60528119],
#        [-0.82488383, -1.51684926],
#        [-0.24921376,  0.92075127],
#        [-1.49046586, -0.49049114],
#        [-0.06705447,  0.23876331],
#        [-1.49747198, -0.10560685],
#        [ 0.89862331, -1.40881156],
#        [-0.27957364,  0.76544708],
#        [ 0.96284614,  0.61014289],
#        [-0.69877355, -0.77409009],
#        [-1.62591764,  1.05579839],
#        [-0.7805117 , -1.57086811],
#        [ 0.85541887,  1.73778635],
#        [-1.02105537, -0.76058538],
#        [-1.70882347,  1.10306488],
#        [ 1.37971067, -1.37504978],
#        [-1.61891151,  0.26577273],
#        [ 0.84958043,  0.69117116],
#        [-1.2861205 ,  1.03554132],
#        [-1.15300409,  1.60273923],
#        [-1.41806922,  1.06255074],
#        [ 1.47896413,  0.38056279],
#        [-1.21489154,  0.1779921 ],
#        [ 0.4420574 ,  1.39341619],
#        [-0.85991446, -0.42296758],
#        [ 0.54481392,  0.81946593],
#        [ 0.85775424,  0.67091409],
#        [-0.49559588, -1.18598381],
#        [-0.59368165, -0.57151941],
#        [-0.07873135, -1.44257334],
#        [ 1.08662104, -1.07794612],
#        [ 1.12281936,  1.73778635],
#        [-1.27327593,  1.15033137],
#        [-1.19504085,  0.17123975],
#        [ 1.56070228, -0.63229062],
#        [-0.30409509, -1.0036702 ],
#        [ 0.59035374,  0.00243085],
#        [ 0.28325186,  1.10981724],
#        [ 0.47592034, -0.14612098],
#        [-1.66912209, -0.78759481],
#        [-0.62053847,  1.36640677],
#        [ 0.03219899, -1.48308748],
#        [-1.58037782,  0.92075127],
#        [-0.1791525 , -0.3284346 ],
#        [ 0.29726411, -0.34869167],
#        [-0.71628887,  0.84647535],
#        [ 0.48292647, -0.34869167],
#        [ 0.19217221,  0.91399891],
#        [-0.34846722, -0.57827177],
#        [ 1.02123053, -1.341288  ],
#        [-1.50798117,  0.96801776],
#        [ 0.69778102, -1.21974559],
#        [ 0.79820216,  0.02268792],
#        [ 1.60273904, -0.85511837],
#        [-1.1331534 , -0.78759481],
#        [ 0.20384909, -0.1596257 ],
#        [-1.48813048, -0.21364454],
#        [ 0.24938891, -1.09145083],
#        [ 0.87994031, -1.341288  ],
#        [ 1.51633014,  1.73103399],
#        [ 1.18353913,  0.46834341],
#        [ 0.27040729, -1.04418434],
#        [ 1.51399477, -1.41556392],
#        [ 0.21669366, -0.8956325 ],
#        [ 0.11160176, -1.39530685],
#        [ 0.83440049, -1.20624088],
#        [-1.06075676, -1.18598381],
#        [ 1.64127273,  1.33264499],
#        [ 1.24659427, -0.13261627],
#        [ 0.67676264,  1.47444446],
#        [-0.08807285, -1.42906863],
#        [ 0.51445404,  0.36705807],
#        [ 1.62258973, -0.63229062],
#        [-1.49863967, -0.75383303],
#        [-1.25576062,  1.20435022],
#        [-0.83539302, -0.84161366],
#        [-1.51615499, -1.29402151],
#        [ 0.23070591,  1.26512143],
#        [ 0.0310313 ,  0.83297064],
#        [-1.27094056, -1.32103093],
#        [-0.61703541, -1.24000266],
#        [ 0.34981006, -0.942899  ],
#        [ 1.59456522,  1.26512143],
#        [ 0.99320602, -0.99016549]])

# %%
sns.distplot(ad_df['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %%
sns.distplot(ad_df['radio'])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %% [markdown]
# ### Model Building

# %%
# Importing the libraries for model building
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %%
# Instantiating each algorithm
lr_ad = LinearRegression()
dtr_ad = DecisionTreeRegressor()
knr_ad = KNeighborsRegressor()
svr_ad = SVR()
rfr_ad = RandomForestRegressor()

# List of instantiated algorithms
algm_ad = [lr_ad, dtr_ad, knr_ad, svr_ad, rfr_ad]

# %%
# Maximum accuracy
maxAccu_ad = 0 

# Best random state value for which accuracy is achieved 
maxRS_ad = 0

for i in range(0,500):
    x_train, x_test,y_train, y_test = train_test_split(X,y, random_state=i, test_size=0.20)
    lr_ad.fit(x_train, y_train)
    pred_train_ad= lr_ad.predict(x_train)
    pred_test_ad= lr_ad.predict(x_test)
    score_train_ad = lr_ad.score(x_train, y_train)
    score_test_ad = lr_ad.score(x_test, y_test)
    r2_lr_ad = r2_score(y_test, pred_test_ad)
    print(f'----------------At random State {i} ------------------')
    print(f"Training score is {score_train_ad}")
    print(f"Testing score is {score_test_ad}")
    print(f'r2 score of {lr_ad} is {r2_lr_ad}')
    
    if r2_lr_ad > maxAccu_ad:
        maxAccu_ad = r2_lr_ad
        maxRS_ad = i
        print(f"Maximum score of {lr_ad} is {r2_lr_ad} at Random state {i}")
        print('\n')
# Out:
# ----------------At random State 0 ------------------
# Training score is 0.906590009997456
# Testing score is 0.8604541663186569
# r2 score of LinearRegression() is 0.8604541663186569
# Maximum score of LinearRegression() is 0.8604541663186569 at Random state 0
#
#
# ----------------At random State 1 ------------------
# Training score is 0.8958528468776601
# Testing score is 0.8947344950027069
# r2 score of LinearRegression() is 0.8947344950027069
# Maximum score of LinearRegression() is 0.8947344950027069 at Random state 1
#
#
# ----------------At random State 2 ------------------
# Training score is 0.9148698946311157
# Testing score is 0.7629335290913725
# r2 score of LinearRegression() is 0.7629335290913725
# ----------------At random State 3 ------------------
# Training score is 0.8930073913590098
# Testing score is 0.9142565569025372
# r2 score of LinearRegression() is 0.9142565569025372
# Maximum score of LinearRegression() is 0.9142565569025372 at Random state 3
#
#
# ----------------At random State 4 ------------------
# Training score is 0.8911657617946168
# Testing score is 0.9086623887492479
# r2 score of LinearRegression() is 0.9086623887492479
# ----------------At random State 5 ------------------
# Training score is 0.8956551156995032
# Testing score is 0.8985603563634559
# r2 score of LinearRegression() is 0.8985603563634559
# ----------------At random State 6 ------------------
# Training score is 0.8914984406883799
# Testing score is 0.9231606203241168
# r2 score of LinearRegression() is 0.9231606203241168
# Maximum score of LinearRegression() is 0.9231606203241168 at Random state 6
#
#
# ----------------At random State 7 ------------------
# Training score is 0.8928993103144962
# Testing score is 0.9095363908842858
# r2 score of LinearRegression() is 0.9095363908842858
# ----------------At random State 8 ------------------
# Training score is 0.9086015041132243
# Testing score is 0.8471658086135851
# r2 score of LinearRegression() is 0.8471658086135851
# ----------------At random State 9 ------------------
# Training score is 0.8897265958178805
# Testing score is 0.9258743223517101
# r2 score of LinearRegression() is 0.9258743223517101
# Maximum score of LinearRegression() is 0.9258743223517101 at Random state 9
#
#
# ----------------At random State 10 ------------------
# Training score is 0.9208213397821704
# Testing score is 0.8354496662944216
# r2 score of LinearRegression() is 0.8354496662944216
# ----------------At random State 11 ------------------
# Training score is 0.9104028503777378
# Testing score is 0.8489631946145386
# r2 score of LinearRegression() is 0.8489631946145386
# ----------------At random State 12 ------------------
# Training score is 0.8911551108610992
# Testing score is 0.9144076547872573
# r2 score of LinearRegression() is 0.9144076547872573
# ----------------At random State 13 ------------------
# Training score is 0.8868206875129513
# Testing score is 0.9313591613710436
# r2 score of LinearRegression() is 0.9313591613710436
# Maximum score of LinearRegression() is 0.9313591613710436 at Random state 13
#
#
# ----------------At random State 14 ------------------
# Training score is 0.9086245650839918
# Testing score is 0.8549231685159504
# r2 score of LinearRegression() is 0.8549231685159504
# ----------------At random State 15 ------------------
# Training score is 0.8935516303319513
# Testing score is 0.9069663889509988
# r2 score of LinearRegression() is 0.9069663889509988
# ----------------At random State 16 ------------------
# Training score is 0.8925766392816575
# Testing score is 0.9189085409560016
# r2 score of LinearRegression() is 0.9189085409560016
# ----------------At random State 17 ------------------
# Training score is 0.9115936397308523
# Testing score is 0.8266045444323838
# r2 score of LinearRegression() is 0.8266045444323838
# ----------------At random State 18 ------------------
# Training score is 0.9053228185480983
# Testing score is 0.8718334287685906
# r2 score of LinearRegression() is 0.8718334287685906
# ----------------At random State 19 ------------------
# Training score is 0.8932976814497804
# Testing score is 0.9057638778884525
# r2 score of LinearRegression() is 0.9057638778884525
# ----------------At random State 20 ------------------
# Training score is 0.8938844209583031
# Testing score is 0.9037683221469325
# r2 score of LinearRegression() is 0.9037683221469325
# ----------------At random State 21 ------------------
# Training score is 0.8875852728335466
# Testing score is 0.9221748864860981
# r2 score of LinearRegression() is 0.9221748864860981
# ----------------At random State 22 ------------------
# Training score is 0.8899746930948599
# Testing score is 0.9186100425383739
# r2 score of LinearRegression() is 0.9186100425383739
# ----------------At random State 23 ------------------
# Training score is 0.8921658382335365
# Testing score is 0.9102150258352955
# r2 score of LinearRegression() is 0.9102150258352955
# ----------------At random State 24 ------------------
# Training score is 0.8941389268572582
# Testing score is 0.9083098863786552
# r2 score of LinearRegression() is 0.9083098863786552
# ----------------At random State 25 ------------------
# Training score is 0.9003669669645289
# Testing score is 0.8769136604903008
# r2 score of LinearRegression() is 0.8769136604903008
# ----------------At random State 26 ------------------
# Training score is 0.8998216267053994
# Testing score is 0.8760430483566874
# r2 score of LinearRegression() is 0.8760430483566874
# ----------------At random State 27 ------------------
# Training score is 0.894564761568744
# Testing score is 0.9088215512617351
# r2 score of LinearRegression() is 0.9088215512617351
# ----------------At random State 28 ------------------
# Training score is 0.8995446652969132
# Testing score is 0.8859925984921077
# r2 score of LinearRegression() is 0.8859925984921077
# ----------------At random State 29 ------------------
# Training score is 0.8895343324678261
# Testing score is 0.9134251752292396
# r2 score of LinearRegression() is 0.9134251752292396
# ----------------At random State 30 ------------------
# Training score is 0.8932786847830761
# Testing score is 0.9091751486815922
# r2 score of LinearRegression() is 0.9091751486815922
# ----------------At random State 31 ------------------
# Training score is 0.8858591915312501
# Testing score is 0.9290735806472308
# r2 score of LinearRegression() is 0.9290735806472308
# ----------------At random State 32 ------------------
# Training score is 0.9171517958828699
# Testing score is 0.7776762771019669
# r2 score of LinearRegression() is 0.7776762771019669
# ----------------At random State 33 ------------------
# Training score is 0.8962381230338229
# Testing score is 0.8946083337934851
# r2 score of LinearRegression() is 0.8946083337934851
# ----------------At random State 34 ------------------
# Training score is 0.8970252470434451
# Testing score is 0.8925212329007027
# r2 score of LinearRegression() is 0.8925212329007027
# ----------------At random State 35 ------------------
# Training score is 0.9137022607272962
# Testing score is 0.7998054032958763
# r2 score of LinearRegression() is 0.7998054032958763
# ----------------At random State 36 ------------------
# Training score is 0.8886762086784664
# Testing score is 0.9273258514118152
# r2 score of LinearRegression() is 0.9273258514118152
# ----------------At random State 37 ------------------
# Training score is 0.8995436824337801
# Testing score is 0.8847942649916866
# r2 score of LinearRegression() is 0.8847942649916866
# ----------------At random State 38 ------------------
# Training score is 0.897176861822262
# Testing score is 0.8929081519708879
# r2 score of LinearRegression() is 0.8929081519708879
# ----------------At random State 39 ------------------
# Training score is 0.8987056272397325
# Testing score is 0.8818340402027659
# r2 score of LinearRegression() is 0.8818340402027659
# ----------------At random State 40 ------------------
# Training score is 0.919890324305473
# Testing score is 0.7990603649019938
# r2 score of LinearRegression() is 0.7990603649019938
# ----------------At random State 41 ------------------
# Training score is 0.9004626260067572
# Testing score is 0.8833213230184381
# r2 score of LinearRegression() is 0.8833213230184381
# ----------------At random State 42 ------------------
# Training score is 0.8955982149747163
# Testing score is 0.9005833101920356
# r2 score of LinearRegression() is 0.9005833101920356
# ----------------At random State 43 ------------------
# Training score is 0.8884728077522832
# Testing score is 0.9285742514931038
# r2 score of LinearRegression() is 0.9285742514931038
# ----------------At random State 44 ------------------
# Training score is 0.9065466322433288
# Testing score is 0.8312578733313357
# r2 score of LinearRegression() is 0.8312578733313357
# ----------------At random State 45 ------------------
# Training score is 0.8955870524394062
# Testing score is 0.8987960997436334
# r2 score of LinearRegression() is 0.8987960997436334
# ----------------At random State 46 ------------------
# Training score is 0.9033817970820337
# Testing score is 0.8533353732674608
# r2 score of LinearRegression() is 0.8533353732674608
# ----------------At random State 47 ------------------
# Training score is 0.8986084713586596
# Testing score is 0.8860732324959226
# r2 score of LinearRegression() is 0.8860732324959226
# ----------------At random State 48 ------------------
# Training score is 0.8903192121972714
# Testing score is 0.9202697708845701
# r2 score of LinearRegression() is 0.9202697708845701
# ----------------At random State 49 ------------------
# Training score is 0.9135612304904024
# Testing score is 0.8252260740376274
# r2 score of LinearRegression() is 0.8252260740376274
# ----------------At random State 50 ------------------
# Training score is 0.9012060565410374
# Testing score is 0.8516296176286774
# r2 score of LinearRegression() is 0.8516296176286774
# ----------------At random State 51 ------------------
# Training score is 0.8935451980376733
# Testing score is 0.9082343229128703
# r2 score of LinearRegression() is 0.9082343229128703
# ----------------At random State 52 ------------------
# Training score is 0.9014303227377083
# Testing score is 0.8828455550035642
# r2 score of LinearRegression() is 0.8828455550035642
# ----------------At random State 53 ------------------
# Training score is 0.8886902979306663
# Testing score is 0.9256807945603543
# r2 score of LinearRegression() is 0.9256807945603543
# ----------------At random State 54 ------------------
# Training score is 0.8918470482360566
# Testing score is 0.9183642338020946
# r2 score of LinearRegression() is 0.9183642338020946
# ----------------At random State 55 ------------------
# Training score is 0.8941156795682829
# Testing score is 0.9066436908158182
# r2 score of LinearRegression() is 0.9066436908158182
# ----------------At random State 56 ------------------
# Training score is 0.8987175081453561
# Testing score is 0.8894663179278891
# r2 score of LinearRegression() is 0.8894663179278891
# ----------------At random State 57 ------------------
# Training score is 0.8823833306942153
# Testing score is 0.9414840542748539
# r2 score of LinearRegression() is 0.9414840542748539
# Maximum score of LinearRegression() is 0.9414840542748539 at Random state 57
#
#
# ----------------At random State 58 ------------------
# Training score is 0.9127115881244889
# Testing score is 0.840644189279713
# r2 score of LinearRegression() is 0.840644189279713
# ----------------At random State 59 ------------------
# Training score is 0.8893072693794808
# Testing score is 0.9250802148227734
# r2 score of LinearRegression() is 0.9250802148227734
# ----------------At random State 60 ------------------
# Training score is 0.8914557701376107
# Testing score is 0.9166342793300639
# r2 score of LinearRegression() is 0.9166342793300639
# ----------------At random State 61 ------------------
# Training score is 0.8993441261987152
# Testing score is 0.8801067004451025
# r2 score of LinearRegression() is 0.8801067004451025
# ----------------At random State 62 ------------------
# Training score is 0.9119337220132518
# Testing score is 0.8418439389573147
# r2 score of LinearRegression() is 0.8418439389573147
# ----------------At random State 63 ------------------
# Training score is 0.8944707344524561
# Testing score is 0.9079874623742146
# r2 score of LinearRegression() is 0.9079874623742146
# ----------------At random State 64 ------------------
# Training score is 0.8977692553439597
# Testing score is 0.8817808624081915
# r2 score of LinearRegression() is 0.8817808624081915
# ----------------At random State 65 ------------------
# Training score is 0.8969569676665967
# Testing score is 0.8941482860789514
# r2 score of LinearRegression() is 0.8941482860789514
# ----------------At random State 66 ------------------
# Training score is 0.8985317452914917
# Testing score is 0.8898562764581867
# r2 score of LinearRegression() is 0.8898562764581867
# ----------------At random State 67 ------------------
# Training score is 0.8993177292534198
# Testing score is 0.8835921180915239
# r2 score of LinearRegression() is 0.8835921180915239
# ----------------At random State 68 ------------------
# Training score is 0.8998660151981037
# Testing score is 0.8716984385205893
# r2 score of LinearRegression() is 0.8716984385205893
# ----------------At random State 69 ------------------
# Training score is 0.8870047362847734
# Testing score is 0.9242019523137871
# r2 score of LinearRegression() is 0.9242019523137871
# ----------------At random State 70 ------------------
# Training score is 0.8859812643288401
# Testing score is 0.9275905210288184
# r2 score of LinearRegression() is 0.9275905210288184
# ----------------At random State 71 ------------------
# Training score is 0.9158683291485784
# Testing score is 0.8278759563794178
# r2 score of LinearRegression() is 0.8278759563794178
# ----------------At random State 72 ------------------
# Training score is 0.8935415448166952
# Testing score is 0.9084220969125045
# r2 score of LinearRegression() is 0.9084220969125045
# ----------------At random State 73 ------------------
# Training score is 0.9077493612848183
# Testing score is 0.841547931150848
# r2 score of LinearRegression() is 0.841547931150848
# ----------------At random State 74 ------------------
# Training score is 0.8979110048148204
# Testing score is 0.8807242846603826
# r2 score of LinearRegression() is 0.8807242846603826
# ----------------At random State 75 ------------------
# Training score is 0.8941453595215858
# Testing score is 0.9086655181196018
# r2 score of LinearRegression() is 0.9086655181196018
# ----------------At random State 76 ------------------
# Training score is 0.9091287499766433
# Testing score is 0.7555116399295888
# r2 score of LinearRegression() is 0.7555116399295888
# ----------------At random State 77 ------------------
# Training score is 0.8859752030907149
# Testing score is 0.9378509985902777
# r2 score of LinearRegression() is 0.9378509985902777
# ----------------At random State 78 ------------------
# Training score is 0.8957153331962916
# Testing score is 0.9026717852798298
# r2 score of LinearRegression() is 0.9026717852798298
# ----------------At random State 79 ------------------
# Training score is 0.8917192357013568
# Testing score is 0.9047364552450619
# r2 score of LinearRegression() is 0.9047364552450619
# ----------------At random State 80 ------------------
# Training score is 0.9161649890967616
# Testing score is 0.8069612151730718
# r2 score of LinearRegression() is 0.8069612151730718
# ----------------At random State 81 ------------------
# Training score is 0.9033386460359487
# Testing score is 0.8621899236927318
# r2 score of LinearRegression() is 0.8621899236927318
# ----------------At random State 82 ------------------
# Training score is 0.9148476507641169
# Testing score is 0.8064914434306314
# r2 score of LinearRegression() is 0.8064914434306314
# ----------------At random State 83 ------------------
# Training score is 0.8837451986460145
# Testing score is 0.9387564731476518
# r2 score of LinearRegression() is 0.9387564731476518
# ----------------At random State 84 ------------------
# Training score is 0.8947603287967097
# Testing score is 0.9039147070571136
# r2 score of LinearRegression() is 0.9039147070571136
# ----------------At random State 85 ------------------
# Training score is 0.9083292621292837
# Testing score is 0.8460501064389513
# r2 score of LinearRegression() is 0.8460501064389513
# ----------------At random State 86 ------------------
# Training score is 0.8940549870471213
# Testing score is 0.9105636857330226
# r2 score of LinearRegression() is 0.9105636857330226
# ----------------At random State 87 ------------------
# Training score is 0.9116761371376374
# Testing score is 0.7648619519106628
# r2 score of LinearRegression() is 0.7648619519106628
# ----------------At random State 88 ------------------
# Training score is 0.9087961178136265
# Testing score is 0.8453863342188653
# r2 score of LinearRegression() is 0.8453863342188653
# ----------------At random State 89 ------------------
# Training score is 0.8996373226035996
# Testing score is 0.880476744671727
# r2 score of LinearRegression() is 0.880476744671727
# ----------------At random State 90 ------------------
# Training score is 0.903101620305532
# Testing score is 0.851529250113042
# r2 score of LinearRegression() is 0.851529250113042
# ----------------At random State 91 ------------------
# Training score is 0.8873646570170686
# Testing score is 0.9042424905323366
# r2 score of LinearRegression() is 0.9042424905323366
# ----------------At random State 92 ------------------
# Training score is 0.8791560212812533
# Testing score is 0.9522328786133317
# r2 score of LinearRegression() is 0.9522328786133317
# Maximum score of LinearRegression() is 0.9522328786133317 at Random state 92
#
#
# ----------------At random State 93 ------------------
# Training score is 0.892769417316429
# Testing score is 0.9127357998611332
# r2 score of LinearRegression() is 0.9127357998611332
# ----------------At random State 94 ------------------
# Training score is 0.9080753429764618
# Testing score is 0.8580335447396212
# r2 score of LinearRegression() is 0.8580335447396212
# ----------------At random State 95 ------------------
# Training score is 0.8935627424379108
# Testing score is 0.8953263896202839
# r2 score of LinearRegression() is 0.8953263896202839
# ----------------At random State 96 ------------------
# Training score is 0.9035747240174029
# Testing score is 0.8599769907931797
# r2 score of LinearRegression() is 0.8599769907931797
# ----------------At random State 97 ------------------
# Training score is 0.8894300272274118
# Testing score is 0.9180645040452483
# r2 score of LinearRegression() is 0.9180645040452483
# ----------------At random State 98 ------------------
# Training score is 0.8819307171717308
# Testing score is 0.94002104451544
# r2 score of LinearRegression() is 0.94002104451544
# ----------------At random State 99 ------------------
# Training score is 0.8906197253189246
# Testing score is 0.9202930325720751
# r2 score of LinearRegression() is 0.9202930325720751
# ----------------At random State 100 ------------------
# Training score is 0.8914548581541241
# Testing score is 0.9199248376017183
# r2 score of LinearRegression() is 0.9199248376017183
# ----------------At random State 101 ------------------
# Training score is 0.887652472222269
# Testing score is 0.9303701772020041
# r2 score of LinearRegression() is 0.9303701772020041
# ----------------At random State 102 ------------------
# Training score is 0.8924048432090534
# Testing score is 0.9118740710535874
# r2 score of LinearRegression() is 0.9118740710535874
# ----------------At random State 103 ------------------
# Training score is 0.8876853533772993
# Testing score is 0.9325208010662006
# r2 score of LinearRegression() is 0.9325208010662006
# ----------------At random State 104 ------------------
# Training score is 0.9168905514974071
# Testing score is 0.8199658775474841
# r2 score of LinearRegression() is 0.8199658775474841
# ----------------At random State 105 ------------------
# Training score is 0.8891887647183829
# Testing score is 0.9239451803291476
# r2 score of LinearRegression() is 0.9239451803291476
# ----------------At random State 106 ------------------
# Training score is 0.8958933634612852
# Testing score is 0.8988050725745959
# r2 score of LinearRegression() is 0.8988050725745959
# ----------------At random State 107 ------------------
# Training score is 0.8929257086411292
# Testing score is 0.9099164335139283
# r2 score of LinearRegression() is 0.9099164335139283
# ----------------At random State 108 ------------------
# Training score is 0.8975447064938106
# Testing score is 0.8903357804063347
# r2 score of LinearRegression() is 0.8903357804063347
# ----------------At random State 109 ------------------
# Training score is 0.9096276245939109
# Testing score is 0.8646174152347412
# r2 score of LinearRegression() is 0.8646174152347412
# ----------------At random State 110 ------------------
# Training score is 0.8820440065485304
# Testing score is 0.9410190397461125
# r2 score of LinearRegression() is 0.9410190397461125
# ----------------At random State 111 ------------------
# Training score is 0.909448907975625
# Testing score is 0.8679752898331153
# r2 score of LinearRegression() is 0.8679752898331153
# ----------------At random State 112 ------------------
# Training score is 0.8953937261140363
# Testing score is 0.9039852849304938
# r2 score of LinearRegression() is 0.9039852849304938
# ----------------At random State 113 ------------------
# Training score is 0.8906732328076771
# Testing score is 0.921915220984488
# r2 score of LinearRegression() is 0.921915220984488
# ----------------At random State 114 ------------------
# Training score is 0.883722400455353
# Testing score is 0.9344517547858272
# r2 score of LinearRegression() is 0.9344517547858272
# ----------------At random State 115 ------------------
# Training score is 0.8861652263613018
# Testing score is 0.922462067762157
# r2 score of LinearRegression() is 0.922462067762157
# ----------------At random State 116 ------------------
# Training score is 0.9018167753963571
# Testing score is 0.8768066527368412
# r2 score of LinearRegression() is 0.8768066527368412
# ----------------At random State 117 ------------------
# Training score is 0.8851054172344452
# Testing score is 0.9302830815603919
# r2 score of LinearRegression() is 0.9302830815603919
# ----------------At random State 118 ------------------
# Training score is 0.8943512085461492
# Testing score is 0.9081931371846027
# r2 score of LinearRegression() is 0.9081931371846027
# ----------------At random State 119 ------------------
# Training score is 0.9166354066283914
# Testing score is 0.7982714714483621
# r2 score of LinearRegression() is 0.7982714714483621
# ----------------At random State 120 ------------------
# Training score is 0.9093481844805008
# Testing score is 0.8381474042388484
# r2 score of LinearRegression() is 0.8381474042388484
# ----------------At random State 121 ------------------
# Training score is 0.8936453914924066
# Testing score is 0.9042558872017756
# r2 score of LinearRegression() is 0.9042558872017756
# ----------------At random State 122 ------------------
# Training score is 0.9183263797430954
# Testing score is 0.7927108096874651
# r2 score of LinearRegression() is 0.7927108096874651
# ----------------At random State 123 ------------------
# Training score is 0.8873933846608307
# Testing score is 0.9288236826549474
# r2 score of LinearRegression() is 0.9288236826549474
# ----------------At random State 124 ------------------
# Training score is 0.8971127721826304
# Testing score is 0.8890956717028752
# r2 score of LinearRegression() is 0.8890956717028752
# ----------------At random State 125 ------------------
# Training score is 0.8928818161253781
# Testing score is 0.8981721399931535
# r2 score of LinearRegression() is 0.8981721399931535
# ----------------At random State 126 ------------------
# Training score is 0.8968772977651994
# Testing score is 0.8866277924838019
# r2 score of LinearRegression() is 0.8866277924838019
# ----------------At random State 127 ------------------
# Training score is 0.9091750137389575
# Testing score is 0.8391920673726672
# r2 score of LinearRegression() is 0.8391920673726672
# ----------------At random State 128 ------------------
# Training score is 0.8956884343384603
# Testing score is 0.8927320584167644
# r2 score of LinearRegression() is 0.8927320584167644
# ----------------At random State 129 ------------------
# Training score is 0.8870863128501913
# Testing score is 0.933591678727316
# r2 score of LinearRegression() is 0.933591678727316
# ----------------At random State 130 ------------------
# Training score is 0.8980073592468032
# Testing score is 0.8927160270470907
# r2 score of LinearRegression() is 0.8927160270470907
# ----------------At random State 131 ------------------
# Training score is 0.8938384443296882
# Testing score is 0.9091381081937234
# r2 score of LinearRegression() is 0.9091381081937234
# ----------------At random State 132 ------------------
# Training score is 0.8991483845912761
# Testing score is 0.8822896318229276
# r2 score of LinearRegression() is 0.8822896318229276
# ----------------At random State 133 ------------------
# Training score is 0.9109767833645823
# Testing score is 0.8171592849629148
# r2 score of LinearRegression() is 0.8171592849629148
# ----------------At random State 134 ------------------
# Training score is 0.8905819400805559
# Testing score is 0.9202552587937294
# r2 score of LinearRegression() is 0.9202552587937294
# ----------------At random State 135 ------------------
# Training score is 0.9062839429779472
# Testing score is 0.8632703500617014
# r2 score of LinearRegression() is 0.8632703500617014
# ----------------At random State 136 ------------------
# Training score is 0.908759350848689
# Testing score is 0.8537404418758612
# r2 score of LinearRegression() is 0.8537404418758612
# ----------------At random State 137 ------------------
# Training score is 0.8856103383367844
# Testing score is 0.9325109740768239
# r2 score of LinearRegression() is 0.9325109740768239
# ----------------At random State 138 ------------------
# Training score is 0.8874006738952843
# Testing score is 0.9207864548461977
# r2 score of LinearRegression() is 0.9207864548461977
# ----------------At random State 139 ------------------
# Training score is 0.8770430147787378
# Testing score is 0.9361744072710294
# r2 score of LinearRegression() is 0.9361744072710294
# ----------------At random State 140 ------------------
# Training score is 0.9118319096691778
# Testing score is 0.8339271407132369
# r2 score of LinearRegression() is 0.8339271407132369
# ----------------At random State 141 ------------------
# Training score is 0.891038077561594
# Testing score is 0.9145575120590043
# r2 score of LinearRegression() is 0.9145575120590043
# ----------------At random State 142 ------------------
# Training score is 0.8949937713951628
# Testing score is 0.900773974995044
# r2 score of LinearRegression() is 0.900773974995044
# ----------------At random State 143 ------------------
# Training score is 0.9108417185322092
# Testing score is 0.847412843185019
# r2 score of LinearRegression() is 0.847412843185019
# ----------------At random State 144 ------------------
# Training score is 0.8971535903473533
# Testing score is 0.8933746043369853
# r2 score of LinearRegression() is 0.8933746043369853
# ----------------At random State 145 ------------------
# Training score is 0.9131670908118426
# Testing score is 0.8261030815624991
# r2 score of LinearRegression() is 0.8261030815624991
# ----------------At random State 146 ------------------
# Training score is 0.896438258945105
# Testing score is 0.8983705453504793
# r2 score of LinearRegression() is 0.8983705453504793
# ----------------At random State 147 ------------------
# Training score is 0.9129313990842275
# Testing score is 0.8360292507997679
# r2 score of LinearRegression() is 0.8360292507997679
# ----------------At random State 148 ------------------
# Training score is 0.8913388584642192
# Testing score is 0.9137885116765732
# r2 score of LinearRegression() is 0.9137885116765732
# ----------------At random State 149 ------------------
# Training score is 0.9036519336564673
# Testing score is 0.8605890447061534
# r2 score of LinearRegression() is 0.8605890447061534
# ----------------At random State 150 ------------------
# Training score is 0.8889414967644641
# Testing score is 0.9242011216094176
# r2 score of LinearRegression() is 0.9242011216094176
# ----------------At random State 151 ------------------
# Training score is 0.8801065805087099
# Testing score is 0.9534698621582527
# r2 score of LinearRegression() is 0.9534698621582527
# Maximum score of LinearRegression() is 0.9534698621582527 at Random state 151
#
#
# ----------------At random State 152 ------------------
# Training score is 0.8954384279186121
# Testing score is 0.9021455873605266
# r2 score of LinearRegression() is 0.9021455873605266
# ----------------At random State 153 ------------------
# Training score is 0.8997797648624117
# Testing score is 0.8835810477950785
# r2 score of LinearRegression() is 0.8835810477950785
# ----------------At random State 154 ------------------
# Training score is 0.8853618797408672
# Testing score is 0.9355233909168125
# r2 score of LinearRegression() is 0.9355233909168125
# ----------------At random State 155 ------------------
# Training score is 0.9190459548465848
# Testing score is 0.8063156288490502
# r2 score of LinearRegression() is 0.8063156288490502
# ----------------At random State 156 ------------------
# Training score is 0.8923667415539654
# Testing score is 0.9153472256979366
# r2 score of LinearRegression() is 0.9153472256979366
# ----------------At random State 157 ------------------
# Training score is 0.9119181019763182
# Testing score is 0.8233664549029325
# r2 score of LinearRegression() is 0.8233664549029325
# ----------------At random State 158 ------------------
# Training score is 0.8881914867790343
# Testing score is 0.9243665184236142
# r2 score of LinearRegression() is 0.9243665184236142
# ----------------At random State 159 ------------------
# Training score is 0.88976298214455
# Testing score is 0.9160231187348922
# r2 score of LinearRegression() is 0.9160231187348922
# ----------------At random State 160 ------------------
# Training score is 0.8984172999829467
# Testing score is 0.8804770693024789
# r2 score of LinearRegression() is 0.8804770693024789
# ----------------At random State 161 ------------------
# Training score is 0.8905675285534541
# Testing score is 0.9177469173982511
# r2 score of LinearRegression() is 0.9177469173982511
# ----------------At random State 162 ------------------
# Training score is 0.9020464985816892
# Testing score is 0.8722149135761313
# r2 score of LinearRegression() is 0.8722149135761313
# ----------------At random State 163 ------------------
# Training score is 0.8994242037496704
# Testing score is 0.8851762453746006
# r2 score of LinearRegression() is 0.8851762453746006
# ----------------At random State 164 ------------------
# Training score is 0.877873589855372
# Testing score is 0.9366980067763411
# r2 score of LinearRegression() is 0.9366980067763411
# ----------------At random State 165 ------------------
# Training score is 0.9121543445428029
# Testing score is 0.8329303000936794
# r2 score of LinearRegression() is 0.8329303000936794
# ----------------At random State 166 ------------------
# Training score is 0.9056754350945725
# Testing score is 0.8624374798975588
# r2 score of LinearRegression() is 0.8624374798975588
# ----------------At random State 167 ------------------
# Training score is 0.9051173091694602
# Testing score is 0.8623929828444272
# r2 score of LinearRegression() is 0.8623929828444272
# ----------------At random State 168 ------------------
# Training score is 0.8921175950721612
# Testing score is 0.9119077292839755
# r2 score of LinearRegression() is 0.9119077292839755
# ----------------At random State 169 ------------------
# Training score is 0.8951195230040506
# Testing score is 0.9011251239368202
# r2 score of LinearRegression() is 0.9011251239368202
# ----------------At random State 170 ------------------
# Training score is 0.9073940737401531
# Testing score is 0.8416729232317597
# r2 score of LinearRegression() is 0.8416729232317597
# ----------------At random State 171 ------------------
# Training score is 0.8958817615192024
# Testing score is 0.9017263500932235
# r2 score of LinearRegression() is 0.9017263500932235
# ----------------At random State 172 ------------------
# Training score is 0.8990413997694643
# Testing score is 0.8848463166054534
# r2 score of LinearRegression() is 0.8848463166054534
# ----------------At random State 173 ------------------
# Training score is 0.8910380777944508
# Testing score is 0.9183920971892792
# r2 score of LinearRegression() is 0.9183920971892792
# ----------------At random State 174 ------------------
# Training score is 0.8917355529547184
# Testing score is 0.9088810644525138
# r2 score of LinearRegression() is 0.9088810644525138
# ----------------At random State 175 ------------------
# Training score is 0.8914109065905389
# Testing score is 0.9192584045035173
# r2 score of LinearRegression() is 0.9192584045035173
# ----------------At random State 176 ------------------
# Training score is 0.8981699834500186
# Testing score is 0.8876193164126867
# r2 score of LinearRegression() is 0.8876193164126867
# ----------------At random State 177 ------------------
# Training score is 0.8957747675866705
# Testing score is 0.8983257157407719
# r2 score of LinearRegression() is 0.8983257157407719
# ----------------At random State 178 ------------------
# Training score is 0.8930802799820202
# Testing score is 0.915171858929455
# r2 score of LinearRegression() is 0.915171858929455
# ----------------At random State 179 ------------------
# Training score is 0.8913897550788239
# Testing score is 0.9249852083475224
# r2 score of LinearRegression() is 0.9249852083475224
# ----------------At random State 180 ------------------
# Training score is 0.8967235332665339
# Testing score is 0.8968788460851436
# r2 score of LinearRegression() is 0.8968788460851436
# ----------------At random State 181 ------------------
# Training score is 0.8936920350341497
# Testing score is 0.9105178122098742
# r2 score of LinearRegression() is 0.9105178122098742
# ----------------At random State 182 ------------------
# Training score is 0.8922340569309795
# Testing score is 0.9195432941268534
# r2 score of LinearRegression() is 0.9195432941268534
# ----------------At random State 183 ------------------
# Training score is 0.9069563440832076
# Testing score is 0.8644652807563232
# r2 score of LinearRegression() is 0.8644652807563232
# ----------------At random State 184 ------------------
# Training score is 0.911676148916536
# Testing score is 0.848043531448714
# r2 score of LinearRegression() is 0.848043531448714
# ----------------At random State 185 ------------------
# Training score is 0.8959807313203118
# Testing score is 0.8973710339664205
# r2 score of LinearRegression() is 0.8973710339664205
# ----------------At random State 186 ------------------
# Training score is 0.9128666281307474
# Testing score is 0.7976652475250541
# r2 score of LinearRegression() is 0.7976652475250541
# ----------------At random State 187 ------------------
# Training score is 0.8774614342207246
# Testing score is 0.9369091679398103
# r2 score of LinearRegression() is 0.9369091679398103
# ----------------At random State 188 ------------------
# Training score is 0.8979212391540973
# Testing score is 0.8788834901888691
# r2 score of LinearRegression() is 0.8788834901888691
# ----------------At random State 189 ------------------
# Training score is 0.9207118854267214
# Testing score is 0.7962279411906039
# r2 score of LinearRegression() is 0.7962279411906039
# ----------------At random State 190 ------------------
# Training score is 0.8957992411801095
# Testing score is 0.8991011818122382
# r2 score of LinearRegression() is 0.8991011818122382
# ----------------At random State 191 ------------------
# Training score is 0.8976644788580954
# Testing score is 0.8936504585452079
# r2 score of LinearRegression() is 0.8936504585452079
# ----------------At random State 192 ------------------
# Training score is 0.8989876096183836
# Testing score is 0.879904258269908
# r2 score of LinearRegression() is 0.879904258269908
# ----------------At random State 193 ------------------
# Training score is 0.8897005097483193
# Testing score is 0.9299375684769309
# r2 score of LinearRegression() is 0.9299375684769309
# ----------------At random State 194 ------------------
# Training score is 0.888415375312193
# Testing score is 0.9217447349470407
# r2 score of LinearRegression() is 0.9217447349470407
# ----------------At random State 195 ------------------
# Training score is 0.9100496344344857
# Testing score is 0.8484150023114942
# r2 score of LinearRegression() is 0.8484150023114942
# ----------------At random State 196 ------------------
# Training score is 0.8988811107020979
# Testing score is 0.8881340284844519
# r2 score of LinearRegression() is 0.8881340284844519
# ----------------At random State 197 ------------------
# Training score is 0.9001824292518396
# Testing score is 0.885722803997623
# r2 score of LinearRegression() is 0.885722803997623
# ----------------At random State 198 ------------------
# Training score is 0.9017467504500616
# Testing score is 0.8669092960452304
# r2 score of LinearRegression() is 0.8669092960452304
# ----------------At random State 199 ------------------
# Training score is 0.9051837186043997
# Testing score is 0.8564562385996386
# r2 score of LinearRegression() is 0.8564562385996386
# ----------------At random State 200 ------------------
# Training score is 0.9137783870064747
# Testing score is 0.8378626809082899
# r2 score of LinearRegression() is 0.8378626809082899
# ----------------At random State 201 ------------------
# Training score is 0.8929835266893741
# Testing score is 0.9068705796166381
# r2 score of LinearRegression() is 0.9068705796166381
# ----------------At random State 202 ------------------
# Training score is 0.8859482647903846
# Testing score is 0.9256766734703173
# r2 score of LinearRegression() is 0.9256766734703173
# ----------------At random State 203 ------------------
# Training score is 0.8965317091908336
# Testing score is 0.8972495501846639
# r2 score of LinearRegression() is 0.8972495501846639
# ----------------At random State 204 ------------------
# Training score is 0.896111109182754
# Testing score is 0.896657748789609
# r2 score of LinearRegression() is 0.896657748789609
# ----------------At random State 205 ------------------
# Training score is 0.899622593687882
# Testing score is 0.8823168449807114
# r2 score of LinearRegression() is 0.8823168449807114
# ----------------At random State 206 ------------------
# Training score is 0.9075968291866306
# Testing score is 0.8495998741123991
# r2 score of LinearRegression() is 0.8495998741123991
# ----------------At random State 207 ------------------
# Training score is 0.8895329589863581
# Testing score is 0.9233293121582793
# r2 score of LinearRegression() is 0.9233293121582793
# ----------------At random State 208 ------------------
# Training score is 0.9148427048407919
# Testing score is 0.8463750483633288
# r2 score of LinearRegression() is 0.8463750483633288
# ----------------At random State 209 ------------------
# Training score is 0.9092811614867697
# Testing score is 0.843218953505665
# r2 score of LinearRegression() is 0.843218953505665
# ----------------At random State 210 ------------------
# Training score is 0.9080026585183684
# Testing score is 0.846942927763263
# r2 score of LinearRegression() is 0.846942927763263
# ----------------At random State 211 ------------------
# Training score is 0.8918624819697899
# Testing score is 0.9146222178805902
# r2 score of LinearRegression() is 0.9146222178805902
# ----------------At random State 212 ------------------
# Training score is 0.8921704844481051
# Testing score is 0.9225402729418266
# r2 score of LinearRegression() is 0.9225402729418266
# ----------------At random State 213 ------------------
# Training score is 0.8950002868870979
# Testing score is 0.9055802484964646
# r2 score of LinearRegression() is 0.9055802484964646
# ----------------At random State 214 ------------------
# Training score is 0.8886869413966365
# Testing score is 0.9168226955656795
# r2 score of LinearRegression() is 0.9168226955656795
# ----------------At random State 215 ------------------
# Training score is 0.901116674256712
# Testing score is 0.8679591594663111
# r2 score of LinearRegression() is 0.8679591594663111
# ----------------At random State 216 ------------------
# Training score is 0.8987508990697741
# Testing score is 0.8730318165090161
# r2 score of LinearRegression() is 0.8730318165090161
# ----------------At random State 217 ------------------
# Training score is 0.8861456066645987
# Testing score is 0.9308394811213789
# r2 score of LinearRegression() is 0.9308394811213789
# ----------------At random State 218 ------------------
# Training score is 0.8900938456235026
# Testing score is 0.9167015593571475
# r2 score of LinearRegression() is 0.9167015593571475
# ----------------At random State 219 ------------------
# Training score is 0.8875588773561175
# Testing score is 0.9441251146933586
# r2 score of LinearRegression() is 0.9441251146933586
# ----------------At random State 220 ------------------
# Training score is 0.9031713223509112
# Testing score is 0.8602304884489484
# r2 score of LinearRegression() is 0.8602304884489484
# ----------------At random State 221 ------------------
# Training score is 0.8969267374299346
# Testing score is 0.8896912031000745
# r2 score of LinearRegression() is 0.8896912031000745
# ----------------At random State 222 ------------------
# Training score is 0.9225209115477656
# Testing score is 0.7942319115612391
# r2 score of LinearRegression() is 0.7942319115612391
# ----------------At random State 223 ------------------
# Training score is 0.9051180998348154
# Testing score is 0.8457303660503638
# r2 score of LinearRegression() is 0.8457303660503638
# ----------------At random State 224 ------------------
# Training score is 0.9218758811318709
# Testing score is 0.805499586345925
# r2 score of LinearRegression() is 0.805499586345925
# ----------------At random State 225 ------------------
# Training score is 0.8890360861170857
# Testing score is 0.9165823373847712
# r2 score of LinearRegression() is 0.9165823373847712
# ----------------At random State 226 ------------------
# Training score is 0.9116862908416952
# Testing score is 0.848904471782733
# r2 score of LinearRegression() is 0.848904471782733
# ----------------At random State 227 ------------------
# Training score is 0.8844975471938659
# Testing score is 0.9282098056755754
# r2 score of LinearRegression() is 0.9282098056755754
# ----------------At random State 228 ------------------
# Training score is 0.9094298251560436
# Testing score is 0.8526112646196027
# r2 score of LinearRegression() is 0.8526112646196027
# ----------------At random State 229 ------------------
# Training score is 0.8867238842244844
# Testing score is 0.934389213045965
# r2 score of LinearRegression() is 0.934389213045965
# ----------------At random State 230 ------------------
# Training score is 0.9068823319435633
# Testing score is 0.8558465385038068
# r2 score of LinearRegression() is 0.8558465385038068
# ----------------At random State 231 ------------------
# Training score is 0.8983831637248133
# Testing score is 0.8913465135511126
# r2 score of LinearRegression() is 0.8913465135511126
# ----------------At random State 232 ------------------
# Training score is 0.8935618648811654
# Testing score is 0.9038006689531153
# r2 score of LinearRegression() is 0.9038006689531153
# ----------------At random State 233 ------------------
# Training score is 0.8930222046211549
# Testing score is 0.9135198521789833
# r2 score of LinearRegression() is 0.9135198521789833
# ----------------At random State 234 ------------------
# Training score is 0.880433813829391
# Testing score is 0.9377817288055138
# r2 score of LinearRegression() is 0.9377817288055138
# ----------------At random State 235 ------------------
# Training score is 0.9071098611151713
# Testing score is 0.8646235265308112
# r2 score of LinearRegression() is 0.8646235265308112
# ----------------At random State 236 ------------------
# Training score is 0.9000622516577456
# Testing score is 0.8765338275808197
# r2 score of LinearRegression() is 0.8765338275808197
# ----------------At random State 237 ------------------
# Training score is 0.9035819699016757
# Testing score is 0.8617498076001122
# r2 score of LinearRegression() is 0.8617498076001122
# ----------------At random State 238 ------------------
# Training score is 0.8952392177142436
# Testing score is 0.9085258719382149
# r2 score of LinearRegression() is 0.9085258719382149
# ----------------At random State 239 ------------------
# Training score is 0.8933504884133011
# Testing score is 0.9158975055009032
# r2 score of LinearRegression() is 0.9158975055009032
# ----------------At random State 240 ------------------
# Training score is 0.9210234767474991
# Testing score is 0.8196228678697606
# r2 score of LinearRegression() is 0.8196228678697606
# ----------------At random State 241 ------------------
# Training score is 0.8934166850733933
# Testing score is 0.9089747681500302
# r2 score of LinearRegression() is 0.9089747681500302
# ----------------At random State 242 ------------------
# Training score is 0.8981649333045143
# Testing score is 0.8875305269609297
# r2 score of LinearRegression() is 0.8875305269609297
# ----------------At random State 243 ------------------
# Training score is 0.8928089687316233
# Testing score is 0.9097209086040954
# r2 score of LinearRegression() is 0.9097209086040954
# ----------------At random State 244 ------------------
# Training score is 0.9019776787644904
# Testing score is 0.867033269542195
# r2 score of LinearRegression() is 0.867033269542195
# ----------------At random State 245 ------------------
# Training score is 0.9141543517336508
# Testing score is 0.8048233020386689
# r2 score of LinearRegression() is 0.8048233020386689
# ----------------At random State 246 ------------------
# Training score is 0.9014433584151906
# Testing score is 0.8764187867018104
# r2 score of LinearRegression() is 0.8764187867018104
# ----------------At random State 247 ------------------
# Training score is 0.88888154701064
# Testing score is 0.9245951640431768
# r2 score of LinearRegression() is 0.9245951640431768
# ----------------At random State 248 ------------------
# Training score is 0.9094592269209709
# Testing score is 0.8535255196345146
# r2 score of LinearRegression() is 0.8535255196345146
# ----------------At random State 249 ------------------
# Training score is 0.8938644846050497
# Testing score is 0.909473341234313
# r2 score of LinearRegression() is 0.909473341234313
# ----------------At random State 250 ------------------
# Training score is 0.9053616712538456
# Testing score is 0.8530504607308573
# r2 score of LinearRegression() is 0.8530504607308573
# ----------------At random State 251 ------------------
# Training score is 0.9100787554927365
# Testing score is 0.8306614909140705
# r2 score of LinearRegression() is 0.8306614909140705
# ----------------At random State 252 ------------------
# Training score is 0.9009557812682701
# Testing score is 0.8637644796430908
# r2 score of LinearRegression() is 0.8637644796430908
# ----------------At random State 253 ------------------
# Training score is 0.8945385752117134
# Testing score is 0.9012629036787645
# r2 score of LinearRegression() is 0.9012629036787645
# ----------------At random State 254 ------------------
# Training score is 0.893278902928498
# Testing score is 0.8964030139247903
# r2 score of LinearRegression() is 0.8964030139247903
# ----------------At random State 255 ------------------
# Training score is 0.8974895302336232
# Testing score is 0.8920031649968911
# r2 score of LinearRegression() is 0.8920031649968911
# ----------------At random State 256 ------------------
# Training score is 0.9035588945321162
# Testing score is 0.8486175378084764
# r2 score of LinearRegression() is 0.8486175378084764
# ----------------At random State 257 ------------------
# Training score is 0.8950019921823742
# Testing score is 0.9053068592569863
# r2 score of LinearRegression() is 0.9053068592569863
# ----------------At random State 258 ------------------
# Training score is 0.8892859368460658
# Testing score is 0.9201970596260654
# r2 score of LinearRegression() is 0.9201970596260654
# ----------------At random State 259 ------------------
# Training score is 0.8938123852755743
# Testing score is 0.9053376376490494
# r2 score of LinearRegression() is 0.9053376376490494
# ----------------At random State 260 ------------------
# Training score is 0.8960598474171926
# Testing score is 0.8968684569783789
# r2 score of LinearRegression() is 0.8968684569783789
# ----------------At random State 261 ------------------
# Training score is 0.8974824138967035
# Testing score is 0.8944353914488048
# r2 score of LinearRegression() is 0.8944353914488048
# ...
# Testing score is 0.9238648087233429
# r2 score of LinearRegression() is 0.9238648087233429
# ----------------At random State 412 ------------------
# Training score is 0.8910685207399514
# Testing score is 0.9182096215881098
# r2 score of LinearRegression() is 0.9182096215881098
# ----------------At random State 413 ------------------
# Training score is 0.904144383614418
# Testing score is 0.8639995926386472
# r2 score of LinearRegression() is 0.8639995926386472
# ----------------At random State 414 ------------------
# Training score is 0.8972775858969649
# Testing score is 0.8946470383034986
# r2 score of LinearRegression() is 0.8946470383034986
# ----------------At random State 415 ------------------
# Training score is 0.9012381541893787
# Testing score is 0.8678049116393998
# r2 score of LinearRegression() is 0.8678049116393998
# ----------------At random State 416 ------------------
# Training score is 0.8923555310726009
# Testing score is 0.9070135367616133
# r2 score of LinearRegression() is 0.9070135367616133
# ----------------At random State 417 ------------------
# Training score is 0.8993429970497265
# Testing score is 0.8894731520192406
# r2 score of LinearRegression() is 0.8894731520192406
# ----------------At random State 418 ------------------
# Training score is 0.9150176477692372
# Testing score is 0.768682538490739
# r2 score of LinearRegression() is 0.768682538490739
# ----------------At random State 419 ------------------
# Training score is 0.8949595930611701
# Testing score is 0.9058787052271597
# r2 score of LinearRegression() is 0.9058787052271597
# ----------------At random State 420 ------------------
# Training score is 0.8974341186785804
# Testing score is 0.8938202675696065
# r2 score of LinearRegression() is 0.8938202675696065
# ----------------At random State 421 ------------------
# Training score is 0.8914339093890492
# Testing score is 0.9141421790395033
# r2 score of LinearRegression() is 0.9141421790395033
# ----------------At random State 422 ------------------
# Training score is 0.89178759283203
# Testing score is 0.9007570203722135
# r2 score of LinearRegression() is 0.9007570203722135
# ----------------At random State 423 ------------------
# Training score is 0.9042599692071471
# Testing score is 0.8521302384694495
# r2 score of LinearRegression() is 0.8521302384694495
# ----------------At random State 424 ------------------
# Training score is 0.8881762963104315
# Testing score is 0.927600489519542
# r2 score of LinearRegression() is 0.927600489519542
# ----------------At random State 425 ------------------
# Training score is 0.899061691320737
# Testing score is 0.8861959884037126
# r2 score of LinearRegression() is 0.8861959884037126
# ----------------At random State 426 ------------------
# Training score is 0.8944866867492607
# Testing score is 0.9089728720525944
# r2 score of LinearRegression() is 0.9089728720525944
# ----------------At random State 427 ------------------
# Training score is 0.9106131440734243
# Testing score is 0.8496113912302993
# r2 score of LinearRegression() is 0.8496113912302993
# ----------------At random State 428 ------------------
# Training score is 0.9143317232773829
# Testing score is 0.7858280332722685
# r2 score of LinearRegression() is 0.7858280332722685
# ----------------At random State 429 ------------------
# Training score is 0.8939320459759754
# Testing score is 0.9084370005191476
# r2 score of LinearRegression() is 0.9084370005191476
# ----------------At random State 430 ------------------
# Training score is 0.8939323403531616
# Testing score is 0.9042418433289467
# r2 score of LinearRegression() is 0.9042418433289467
# ----------------At random State 431 ------------------
# Training score is 0.8926953427729095
# Testing score is 0.9066292916918134
# r2 score of LinearRegression() is 0.9066292916918134
# ----------------At random State 432 ------------------
# Training score is 0.8885523657257043
# Testing score is 0.9249481013628552
# r2 score of LinearRegression() is 0.9249481013628552
# ----------------At random State 433 ------------------
# Training score is 0.9066152663012265
# Testing score is 0.8576218042249371
# r2 score of LinearRegression() is 0.8576218042249371
# ----------------At random State 434 ------------------
# Training score is 0.9006871563950826
# Testing score is 0.8613715204895579
# r2 score of LinearRegression() is 0.8613715204895579
# ----------------At random State 435 ------------------
# Training score is 0.9093089162676791
# Testing score is 0.8323609957686116
# r2 score of LinearRegression() is 0.8323609957686116
# ----------------At random State 436 ------------------
# Training score is 0.8894053200664546
# Testing score is 0.923975742204441
# r2 score of LinearRegression() is 0.923975742204441
# ----------------At random State 437 ------------------
# Training score is 0.897652478296795
# Testing score is 0.884600033108454
# r2 score of LinearRegression() is 0.884600033108454
# ----------------At random State 438 ------------------
# Training score is 0.8905768072290774
# Testing score is 0.9187715973440262
# r2 score of LinearRegression() is 0.9187715973440262
# ----------------At random State 439 ------------------
# Training score is 0.8993505846224112
# Testing score is 0.8832862627644611
# r2 score of LinearRegression() is 0.8832862627644611
# ----------------At random State 440 ------------------
# Training score is 0.907705132297539
# Testing score is 0.8431979222850718
# r2 score of LinearRegression() is 0.8431979222850718
# ----------------At random State 441 ------------------
# Training score is 0.8888638939696653
# Testing score is 0.9255997748965304
# r2 score of LinearRegression() is 0.9255997748965304
# ----------------At random State 442 ------------------
# Training score is 0.8947873029495994
# Testing score is 0.8960689241913659
# r2 score of LinearRegression() is 0.8960689241913659
# ----------------At random State 443 ------------------
# Training score is 0.89036697186305
# Testing score is 0.9221987508943705
# r2 score of LinearRegression() is 0.9221987508943705
# ----------------At random State 444 ------------------
# Training score is 0.8891032823400842
# Testing score is 0.918090095894665
# r2 score of LinearRegression() is 0.918090095894665
# ----------------At random State 445 ------------------
# Training score is 0.9101790374159201
# Testing score is 0.8471898905314441
# r2 score of LinearRegression() is 0.8471898905314441
# ----------------At random State 446 ------------------
# Training score is 0.9002323139431526
# Testing score is 0.8755668621566859
# r2 score of LinearRegression() is 0.8755668621566859
# ----------------At random State 447 ------------------
# Training score is 0.9009675702687935
# Testing score is 0.8772477306678972
# r2 score of LinearRegression() is 0.8772477306678972
# ----------------At random State 448 ------------------
# Training score is 0.8948645664136802
# Testing score is 0.9067748592507273
# r2 score of LinearRegression() is 0.9067748592507273
# ----------------At random State 449 ------------------
# Training score is 0.8927888426237791
# Testing score is 0.9099715993461994
# r2 score of LinearRegression() is 0.9099715993461994
# ----------------At random State 450 ------------------
# Training score is 0.9017322885920092
# Testing score is 0.8601383999823076
# r2 score of LinearRegression() is 0.8601383999823076
# ----------------At random State 451 ------------------
# Training score is 0.8895122046294374
# Testing score is 0.9218096057856455
# r2 score of LinearRegression() is 0.9218096057856455
# ----------------At random State 452 ------------------
# Training score is 0.8975451478297554
# Testing score is 0.8870363817006774
# r2 score of LinearRegression() is 0.8870363817006774
# ----------------At random State 453 ------------------
# Training score is 0.8985955427725958
# Testing score is 0.88899587526345
# r2 score of LinearRegression() is 0.88899587526345
# ----------------At random State 454 ------------------
# Training score is 0.9062418161269378
# Testing score is 0.8582249829978605
# r2 score of LinearRegression() is 0.8582249829978605
# ----------------At random State 455 ------------------
# Training score is 0.8890813001392573
# Testing score is 0.9193971687045941
# r2 score of LinearRegression() is 0.9193971687045941
# ----------------At random State 456 ------------------
# Training score is 0.9015898473062294
# Testing score is 0.8826832732627463
# r2 score of LinearRegression() is 0.8826832732627463
# ----------------At random State 457 ------------------
# Training score is 0.89776302299246
# Testing score is 0.8900097892678478
# r2 score of LinearRegression() is 0.8900097892678478
# ----------------At random State 458 ------------------
# Training score is 0.8834650882913013
# Testing score is 0.9408796796210934
# r2 score of LinearRegression() is 0.9408796796210934
# ----------------At random State 459 ------------------
# Training score is 0.8936898577164838
# Testing score is 0.9067920397636983
# r2 score of LinearRegression() is 0.9067920397636983
# ----------------At random State 460 ------------------
# Training score is 0.8957916155029647
# Testing score is 0.901232629123329
# r2 score of LinearRegression() is 0.901232629123329
# ----------------At random State 461 ------------------
# Training score is 0.9130872544255466
# Testing score is 0.8151786855706709
# r2 score of LinearRegression() is 0.8151786855706709
# ----------------At random State 462 ------------------
# Training score is 0.8941127911498754
# Testing score is 0.902279677001316
# r2 score of LinearRegression() is 0.902279677001316
# ----------------At random State 463 ------------------
# Training score is 0.8922803256454401
# Testing score is 0.9121654736555014
# r2 score of LinearRegression() is 0.9121654736555014
# ----------------At random State 464 ------------------
# Training score is 0.8903128195262109
# Testing score is 0.9017662613189485
# r2 score of LinearRegression() is 0.9017662613189485
# ----------------At random State 465 ------------------
# Training score is 0.8986114871472523
# Testing score is 0.8871058241706058
# r2 score of LinearRegression() is 0.8871058241706058
# ----------------At random State 466 ------------------
# Training score is 0.8888001617580225
# Testing score is 0.9187619519776059
# r2 score of LinearRegression() is 0.9187619519776059
# ----------------At random State 467 ------------------
# Training score is 0.8919541418126957
# Testing score is 0.9085996003044737
# r2 score of LinearRegression() is 0.9085996003044737
# ----------------At random State 468 ------------------
# Training score is 0.900182130555815
# Testing score is 0.8713898022908775
# r2 score of LinearRegression() is 0.8713898022908775
# ----------------At random State 469 ------------------
# Training score is 0.8945196626266073
# Testing score is 0.9074881318934358
# r2 score of LinearRegression() is 0.9074881318934358
# ----------------At random State 470 ------------------
# Training score is 0.8974710947291588
# Testing score is 0.8950402137348588
# r2 score of LinearRegression() is 0.8950402137348588
# ----------------At random State 471 ------------------
# Training score is 0.8957168480170968
# Testing score is 0.898363321743737
# r2 score of LinearRegression() is 0.898363321743737
# ----------------At random State 472 ------------------
# Training score is 0.8973643389629324
# Testing score is 0.8911907946213053
# r2 score of LinearRegression() is 0.8911907946213053
# ----------------At random State 473 ------------------
# Training score is 0.8889221760255346
# Testing score is 0.9204057110616309
# r2 score of LinearRegression() is 0.9204057110616309
# ----------------At random State 474 ------------------
# Training score is 0.8965568468453953
# Testing score is 0.8978803064214973
# r2 score of LinearRegression() is 0.8978803064214973
# ----------------At random State 475 ------------------
# Training score is 0.896272104883386
# Testing score is 0.8987550249705609
# r2 score of LinearRegression() is 0.8987550249705609
# ----------------At random State 476 ------------------
# Training score is 0.8870646376357688
# Testing score is 0.921990407818543
# r2 score of LinearRegression() is 0.921990407818543
# ----------------At random State 477 ------------------
# Training score is 0.89466688436328
# Testing score is 0.9016754481373078
# r2 score of LinearRegression() is 0.9016754481373078
# ----------------At random State 478 ------------------
# Training score is 0.90780193051301
# Testing score is 0.8565861992925925
# r2 score of LinearRegression() is 0.8565861992925925
# ----------------At random State 479 ------------------
# Training score is 0.8885114561041757
# Testing score is 0.9197770747126658
# r2 score of LinearRegression() is 0.9197770747126658
# ----------------At random State 480 ------------------
# Training score is 0.894929556857192
# Testing score is 0.9053928506243931
# r2 score of LinearRegression() is 0.9053928506243931
# ----------------At random State 481 ------------------
# Training score is 0.8980903182191547
# Testing score is 0.8919374895803703
# r2 score of LinearRegression() is 0.8919374895803703
# ----------------At random State 482 ------------------
# Training score is 0.9077438692473957
# Testing score is 0.8619062396327571
# r2 score of LinearRegression() is 0.8619062396327571
# ----------------At random State 483 ------------------
# Training score is 0.8854471305255992
# Testing score is 0.9340729432032356
# r2 score of LinearRegression() is 0.9340729432032356
# ----------------At random State 484 ------------------
# Training score is 0.890091396956139
# Testing score is 0.9168366919559305
# r2 score of LinearRegression() is 0.9168366919559305
# ----------------At random State 485 ------------------
# Training score is 0.8904532277100016
# Testing score is 0.9183501554426117
# r2 score of LinearRegression() is 0.9183501554426117
# ----------------At random State 486 ------------------
# Training score is 0.8914902161648042
# Testing score is 0.9135425495726536
# r2 score of LinearRegression() is 0.9135425495726536
# ----------------At random State 487 ------------------
# Training score is 0.9055667300124958
# Testing score is 0.8589119572769996
# r2 score of LinearRegression() is 0.8589119572769996
# ----------------At random State 488 ------------------
# Training score is 0.899851181754811
# Testing score is 0.8823505352285602
# r2 score of LinearRegression() is 0.8823505352285602
# ----------------At random State 489 ------------------
# Training score is 0.9061435344595286
# Testing score is 0.8093766656902024
# r2 score of LinearRegression() is 0.8093766656902024
# ----------------At random State 490 ------------------
# Training score is 0.9038603191059515
# Testing score is 0.8616712263087556
# r2 score of LinearRegression() is 0.8616712263087556
# ----------------At random State 491 ------------------
# Training score is 0.888706364301403
# Testing score is 0.9326859496887867
# r2 score of LinearRegression() is 0.9326859496887867
# ----------------At random State 492 ------------------
# Training score is 0.9008273229162359
# Testing score is 0.8656878471662194
# r2 score of LinearRegression() is 0.8656878471662194
# ----------------At random State 493 ------------------
# Training score is 0.8893654904207545
# Testing score is 0.909777791428207
# r2 score of LinearRegression() is 0.909777791428207
# ----------------At random State 494 ------------------
# Training score is 0.915528859669886
# Testing score is 0.7900257475937909
# r2 score of LinearRegression() is 0.7900257475937909
# ----------------At random State 495 ------------------
# Training score is 0.8802471920761177
# Testing score is 0.9327318988231321
# r2 score of LinearRegression() is 0.9327318988231321
# ----------------At random State 496 ------------------
# Training score is 0.8923248233381227
# Testing score is 0.8981425946084154
# r2 score of LinearRegression() is 0.8981425946084154
# ----------------At random State 497 ------------------
# Training score is 0.8914580566109622
# Testing score is 0.9181314036363369
# r2 score of LinearRegression() is 0.9181314036363369
# ----------------At random State 498 ------------------
# Training score is 0.8863789498702039
# Testing score is 0.9319944034322253
# r2 score of LinearRegression() is 0.9319944034322253
# ----------------At random State 499 ------------------
# Training score is 0.8954835502243528
# Testing score is 0.8969194616870166
# r2 score of LinearRegression() is 0.8969194616870166

# %% [markdown]
# ###### Getting best score of 95.34% at Random State 151

# %% [markdown]
# #### Training with different models

# %%
algm_ad = [lr_ad, dtr_ad, knr_ad, svr_ad, rfr_ad]

for m in algm_ad:
    x_train, x_test,y_train, y_test = train_test_split(X,y, random_state=151, test_size=0.20)
    m.fit(x_train, y_train)
    pred_ad =m.predict(x_test)
    print(f'----------------------Model results for {m} ------------------------')
    print(f'Score of {m} is {m.score(x_train, y_train)}')
    print(f'Testing Score of {m} is {m.score(x_test, y_test)}')
    print(f"R2 Score of {m} is  {r2_score(y_test, pred_ad)}")
    print(f"Mean Squared error of {m} is {mean_squared_error(y_test, pred_ad)}")
    print(f"Root Mean Squared error of {m} is {np.sqrt(mean_squared_error(y_test, pred_ad))}")
    print('\n')
# Out:
# ----------------------Model results for LinearRegression() ------------------------
# Score of LinearRegression() is 0.8801065805087099
# Testing Score of LinearRegression() is 0.9534698621582527
# R2 Score of LinearRegression() is  0.9534698621582527
# Mean Squared error of LinearRegression() is 1.4360177670857879
# Root Mean Squared error of LinearRegression() is 1.1983395875484495
#
#
# ----------------------Model results for DecisionTreeRegressor() ------------------------
# Score of DecisionTreeRegressor() is 1.0
# Testing Score of DecisionTreeRegressor() is 0.9637014331493968
# R2 Score of DecisionTreeRegressor() is  0.9637014331493968
# Mean Squared error of DecisionTreeRegressor() is 1.12025
# Root Mean Squared error of DecisionTreeRegressor() is 1.0584186317332098
#
#
# ----------------------Model results for KNeighborsRegressor() ------------------------
# Score of KNeighborsRegressor() is 0.9831800040277207
# Testing Score of KNeighborsRegressor() is 0.9715696598740851
# R2 Score of KNeighborsRegressor() is  0.9715696598740851
# Mean Squared error of KNeighborsRegressor() is 0.8774199999999993
# Root Mean Squared error of KNeighborsRegressor() is 0.9367069979454618
#
#
# ----------------------Model results for SVR() ------------------------
# Score of SVR() is 0.9558475487115049
# Testing Score of SVR() is 0.9626677953624336
# R2 Score of SVR() is  0.9626677953624336
# Mean Squared error of SVR() is 1.1521502327450368
# Root Mean Squared error of SVR() is 1.0733826124663268
#
#
# ----------------------Model results for RandomForestRegressor() ------------------------
# Score of RandomForestRegressor() is 0.9969702099511072
# Testing Score of RandomForestRegressor() is 0.9782274099947833
# R2 Score of RandomForestRegressor() is  0.9782274099947833
# Mean Squared error of RandomForestRegressor() is 0.6719478499999976
# Root Mean Squared error of RandomForestRegressor() is 0.8197242524166267

# %% [markdown]
# #### Observation
# 1. Out of the 5 models tested Random forest is giving better results
# 2. Next we will perform cross validation for all the models, then decide the best model

# %% [markdown]
# ### Cross Validation of Each model

# %%
# Before checking all the models we will identify best 'cv' value using Linear Regression 
from sklearn.model_selection import cross_val_score
max_cvscore_ad = 0 
max_cv_ad = 0
for j in range(2,15):
    cv_score_ad = cross_val_score(lr_ad, X,y,cv=j)
    cv_mean_ad = cv_score_ad.mean()
    print(f"At cross fold {j} the cv score is {cv_mean_ad}")
    print('\n') 
    
    if cv_mean_ad > max_cvscore_ad:
        max_cvscore_ad = cv_mean_ad
        max_cv_ad = j
        print(f"At cross fold {j} the Maximum CV score is {max_cvscore_ad}")
# Out:
# At cross fold 2 the cv score is 0.8942166468026784
#
#
# At cross fold 2 the Maximum CV score is 0.8942166468026784
# At cross fold 3 the cv score is 0.8931635501481657
#
#
# At cross fold 4 the cv score is 0.8916530235661282
#
#
# At cross fold 5 the cv score is 0.889282957306453
#
#
# At cross fold 6 the cv score is 0.8910268337384196
#
#
# At cross fold 7 the cv score is 0.887824825599243
#
#
# At cross fold 8 the cv score is 0.8845638944511245
#
#
# At cross fold 9 the cv score is 0.8839789119628068
#
#
# At cross fold 10 the cv score is 0.8869670516810129
#
#
# At cross fold 11 the cv score is 0.8789617225099257
#
#
# At cross fold 12 the cv score is 0.8862330509464184
#
#
# At cross fold 13 the cv score is 0.8857367723878651
#
#
# At cross fold 14 the cv score is 0.8761527205995734

# %% [markdown]
# ##### Getting better results at cross validation of '2'

# %%
# Using cross validation for all the models
# algm_ad is a list containing the instance of all the models

for m_cv in algm_ad:
    cv_score = cross_val_score(m_cv,X,y,cv=2)
    cv_mean = cv_score.mean()
    print('---------------------------------------------------')
    print(f"The cross validation score is {cv_mean} for {m_cv}")
    print('\n')
# Out:
# ---------------------------------------------------
# The cross validation score is 0.8942166468026784 for LinearRegression()
#
#
# ---------------------------------------------------
# The cross validation score is 0.9435125696607483 for DecisionTreeRegressor()
#
#
# ---------------------------------------------------
# The cross validation score is 0.9569484442649197 for KNeighborsRegressor()
#
#
# ---------------------------------------------------
# The cross validation score is 0.929448898538536 for SVR()
#
#
# ---------------------------------------------------
# The cross validation score is 0.9723925966714111 for RandomForestRegressor()

# %% [markdown]
# ##### As we can even with cross validation the Random forest Regressor is having better score. Hence proceeding with Hyper parameter tuning using Random Forest Regressor

# %% [markdown]
# ### Hyper Parameter tuning

# %%
# Tuning for Random Forest Regressor
from sklearn.model_selection import GridSearchCV

# creating parameter list for GridSearchCV
parameter_rf_ad = {'n_estimators':[100,200,300],
                   'max_depth': [2,4,6,8],
                   'criterion': ['mse','mae'], 
                   'max_features':['auto','sqrt','log2']}

# %%
grid_rfr = GridSearchCV(rfr_ad,
                     parameter_rf_ad,
                     cv=2)

# %%
# Training grid search 
grid_rfr.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'], 'max_depth': [2, 4, 6, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300]})

# %%
# Getting the best parameters
grid_rfr.best_params_
# Out:
# {'criterion': 'mae',
#  'max_depth': 8,
#  'max_features': 'auto',
#  'n_estimators': 300}

# %%
# Best Estimator
grid_rfr.best_estimator_
# Out:
# RandomForestRegressor(criterion='mae', max_depth=8, n_estimators=300)

# %%
grid_rfr_pred=grid_rfr.best_estimator_.predict(x_test)

print(f'Final Accuracy with {rfr_ad}')
r2_score(y_test,grid_rfr_pred)
# Out:
# Final Accuracy with RandomForestRegressor()
# 0.9825331483077586

# %% [markdown]
# ### Pickling

# %%
# Pickling of the file or serialization of a file
import joblib
joblib.dump(grid_rfr.best_estimator_,"Advertising.pkl")
# Out:
# ['Advertising.pkl']

# %%
advertising_model = joblib.load('Advertising.pkl')
advertising_result = advertising_model.score(x_test, y_test)
print(advertising_result*100)
# Out:
# 98.25331483077586

# %% [markdown]
# #### Conclusion

# %%
advertising_conclusion = pd.DataFrame([advertising_model.predict(x_test),y_test], index=['Predicted', 'Original'])
advertising_conclusion
# Out:
#               0          1          2          3         4          5   \
# Predicted  8.968  12.886833  11.324833  10.325833  8.299667  21.078167
# Original   8.400  13.200000  11.400000  10.100000  8.000000  21.200000
#
#                6         7      8         9   ...       30       31       32  \
# Predicted  24.875  7.526833  8.633  6.271333  ...  12.7405  12.1705  11.3435
# Original   24.200  6.900000  9.500  4.800000  ...  12.8000  12.3000  11.6000
#
#                   33         34         35     36      37         38  \
# Predicted  11.362167  19.749333  19.364833  6.938  20.308  20.149167
# Original   11.700000  18.900000  18.900000  5.900  20.200  20.200000
#
#                   39
# Predicted  15.545167
# Original   16.700000
#
# [2 rows x 40 columns]

# %% [markdown]
# #### Achieved the score of 98.25% with Random forest Regressor. The model is predicting the sales values very well as plotted in the DataFrame above

# %% [markdown]
# ##### Thank you
